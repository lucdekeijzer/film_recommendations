# %%
# !pip install colorama
# !pip install scikit_learn
# !pip install Flask
# !pip install beautifulsoup4
# !pip install bs4
# Out:
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.4
# Requirement already satisfied: scikit_learn in /usr/local/lib/python3.7/dist-packages (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.19.5)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)

# %%
# !pip install google
# Out:
# Requirement already satisfied: google in /usr/local/lib/python3.7/dist-packages (2.0.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from google) (4.6.3)

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
with open('intents.json') as file:
    data = json.load(file)
    
training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 16)            16000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 153
# =================================================================
# Total params: 16,697
# Trainable params: 16,697
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 7ms/step - loss: 2.2007 - accuracy: 0.0889
# Epoch 2/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1988 - accuracy: 0.0667
# Epoch 3/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1975 - accuracy: 0.0667
# Epoch 4/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1960 - accuracy: 0.0889
# Epoch 5/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1949 - accuracy: 0.1333
# Epoch 6/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1938 - accuracy: 0.1333
# Epoch 7/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1931 - accuracy: 0.1111
# Epoch 8/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1924 - accuracy: 0.1333
# Epoch 9/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1915 - accuracy: 0.2000
# Epoch 10/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1909 - accuracy: 0.1556
# Epoch 11/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1905 - accuracy: 0.1556
# Epoch 12/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1899 - accuracy: 0.1556
# Epoch 13/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1892 - accuracy: 0.1556
# Epoch 14/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1885 - accuracy: 0.1778
# Epoch 15/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.1880 - accuracy: 0.2000
# Epoch 16/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1870 - accuracy: 0.1333
# Epoch 17/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1860 - accuracy: 0.1111
# Epoch 18/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1853 - accuracy: 0.1333
# Epoch 19/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1842 - accuracy: 0.1333
# Epoch 20/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1832 - accuracy: 0.1333
# Epoch 21/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1822 - accuracy: 0.1333
# Epoch 22/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1812 - accuracy: 0.1333
# Epoch 23/500
# 2/2 [==============================] - 0s 12ms/step - loss: 2.1801 - accuracy: 0.1333
# Epoch 24/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1792 - accuracy: 0.1333
# Epoch 25/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1780 - accuracy: 0.1333
# Epoch 26/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1769 - accuracy: 0.1333
# Epoch 27/500
# 2/2 [==============================] - 0s 15ms/step - loss: 2.1758 - accuracy: 0.1333
# Epoch 28/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1743 - accuracy: 0.1333
# Epoch 29/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1731 - accuracy: 0.1333
# Epoch 30/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1716 - accuracy: 0.1333
# Epoch 31/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1702 - accuracy: 0.1333
# Epoch 32/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1687 - accuracy: 0.1333
# Epoch 33/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1668 - accuracy: 0.1333
# Epoch 34/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1654 - accuracy: 0.1333
# Epoch 35/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1636 - accuracy: 0.1556
# Epoch 36/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1621 - accuracy: 0.2222
# Epoch 37/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1603 - accuracy: 0.2667
# Epoch 38/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.1580 - accuracy: 0.2667
# Epoch 39/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.1565 - accuracy: 0.3111
# Epoch 40/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1541 - accuracy: 0.3111
# Epoch 41/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1522 - accuracy: 0.3111
# Epoch 42/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1500 - accuracy: 0.3111
# Epoch 43/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1479 - accuracy: 0.3111
# Epoch 44/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1454 - accuracy: 0.3111
# Epoch 45/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1433 - accuracy: 0.3111
# Epoch 46/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1407 - accuracy: 0.3111
# Epoch 47/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1383 - accuracy: 0.3111
# Epoch 48/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1360 - accuracy: 0.3111
# Epoch 49/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1335 - accuracy: 0.2667
# Epoch 50/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1313 - accuracy: 0.2222
# Epoch 51/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1286 - accuracy: 0.1778
# Epoch 52/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1267 - accuracy: 0.1556
# Epoch 53/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1240 - accuracy: 0.1556
# Epoch 54/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1219 - accuracy: 0.1333
# Epoch 55/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1193 - accuracy: 0.1333
# Epoch 56/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1169 - accuracy: 0.1333
# Epoch 57/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1147 - accuracy: 0.1556
# Epoch 58/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1120 - accuracy: 0.1778
# Epoch 59/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.1094 - accuracy: 0.2000
# Epoch 60/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1067 - accuracy: 0.2444
# Epoch 61/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1039 - accuracy: 0.2444
# Epoch 62/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1011 - accuracy: 0.2889
# Epoch 63/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0983 - accuracy: 0.2889
# Epoch 64/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0953 - accuracy: 0.3111
# Epoch 65/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0923 - accuracy: 0.3111
# Epoch 66/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0892 - accuracy: 0.2889
# Epoch 67/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0862 - accuracy: 0.2889
# Epoch 68/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0825 - accuracy: 0.2889
# Epoch 69/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0792 - accuracy: 0.2889
# Epoch 70/500
# 2/2 [==============================] - 0s 13ms/step - loss: 2.0756 - accuracy: 0.2889
# Epoch 71/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0721 - accuracy: 0.2889
# Epoch 72/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0684 - accuracy: 0.2889
# Epoch 73/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0645 - accuracy: 0.2667
# Epoch 74/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0606 - accuracy: 0.2444
# Epoch 75/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0562 - accuracy: 0.2444
# Epoch 76/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0522 - accuracy: 0.2444
# Epoch 77/500
# 2/2 [==============================] - 0s 15ms/step - loss: 2.0483 - accuracy: 0.2444
# Epoch 78/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0433 - accuracy: 0.2444
# Epoch 79/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0388 - accuracy: 0.2444
# Epoch 80/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0339 - accuracy: 0.2667
# Epoch 81/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0289 - accuracy: 0.2667
# Epoch 82/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0247 - accuracy: 0.2222
# Epoch 83/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0197 - accuracy: 0.2889
# Epoch 84/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0143 - accuracy: 0.2222
# Epoch 85/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0085 - accuracy: 0.1778
# Epoch 86/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0031 - accuracy: 0.1778
# Epoch 87/500
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9967 - accuracy: 0.1778
# Epoch 88/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9903 - accuracy: 0.1778
# Epoch 89/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9837 - accuracy: 0.1778
# Epoch 90/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9770 - accuracy: 0.2222
# Epoch 91/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9700 - accuracy: 0.2444
# Epoch 92/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9631 - accuracy: 0.2444
# Epoch 93/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9553 - accuracy: 0.2444
# Epoch 94/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9482 - accuracy: 0.2444
# Epoch 95/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9404 - accuracy: 0.2444
# Epoch 96/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9331 - accuracy: 0.2444
# Epoch 97/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9258 - accuracy: 0.2444
# Epoch 98/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9179 - accuracy: 0.2444
# Epoch 99/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9093 - accuracy: 0.2667
# Epoch 100/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9011 - accuracy: 0.2667
# Epoch 101/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8928 - accuracy: 0.2667
# Epoch 102/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8840 - accuracy: 0.2667
# Epoch 103/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8753 - accuracy: 0.2889
# Epoch 104/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8656 - accuracy: 0.4000
# Epoch 105/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8568 - accuracy: 0.4667
# Epoch 106/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8483 - accuracy: 0.4667
# Epoch 107/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8388 - accuracy: 0.5111
# Epoch 108/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8302 - accuracy: 0.5111
# Epoch 109/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8206 - accuracy: 0.5111
# Epoch 110/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8116 - accuracy: 0.5111
# Epoch 111/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8022 - accuracy: 0.5111
# Epoch 112/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7922 - accuracy: 0.5111
# Epoch 113/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7827 - accuracy: 0.5333
# Epoch 114/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7726 - accuracy: 0.5333
# Epoch 115/500
# 2/2 [==============================] - 0s 29ms/step - loss: 1.7636 - accuracy: 0.5333
# Epoch 116/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7531 - accuracy: 0.5333
# Epoch 117/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7431 - accuracy: 0.5333
# Epoch 118/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7326 - accuracy: 0.5333
# Epoch 119/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7216 - accuracy: 0.5333
# Epoch 120/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7117 - accuracy: 0.5333
# Epoch 121/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7008 - accuracy: 0.5333
# Epoch 122/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6902 - accuracy: 0.5333
# Epoch 123/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.6796 - accuracy: 0.5333
# Epoch 124/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6687 - accuracy: 0.5333
# Epoch 125/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6588 - accuracy: 0.5333
# Epoch 126/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6475 - accuracy: 0.5333
# Epoch 127/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6366 - accuracy: 0.5333
# Epoch 128/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6258 - accuracy: 0.5333
# Epoch 129/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6152 - accuracy: 0.5333
# Epoch 130/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6035 - accuracy: 0.5333
# Epoch 131/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.5928 - accuracy: 0.5333
# Epoch 132/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5819 - accuracy: 0.5333
# Epoch 133/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5700 - accuracy: 0.5333
# Epoch 134/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5589 - accuracy: 0.5333
# Epoch 135/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.5484 - accuracy: 0.5333
# Epoch 136/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5381 - accuracy: 0.5333
# Epoch 137/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5270 - accuracy: 0.5333
# Epoch 138/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5158 - accuracy: 0.5333
# Epoch 139/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5036 - accuracy: 0.5333
# Epoch 140/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4926 - accuracy: 0.5333
# Epoch 141/500
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4807 - accuracy: 0.5333
# Epoch 142/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.4696 - accuracy: 0.5333
# Epoch 143/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4587 - accuracy: 0.5333
# Epoch 144/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4476 - accuracy: 0.5333
# Epoch 145/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4355 - accuracy: 0.5333
# Epoch 146/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4230 - accuracy: 0.5333
# Epoch 147/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4109 - accuracy: 0.5778
# Epoch 148/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3999 - accuracy: 0.5556
# Epoch 149/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3873 - accuracy: 0.5778
# Epoch 150/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3752 - accuracy: 0.6222
# Epoch 151/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3639 - accuracy: 0.6222
# Epoch 152/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3537 - accuracy: 0.6222
# Epoch 153/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3417 - accuracy: 0.6222
# Epoch 154/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3299 - accuracy: 0.6222
# Epoch 155/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3183 - accuracy: 0.6222
# Epoch 156/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3073 - accuracy: 0.6222
# Epoch 157/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2961 - accuracy: 0.6222
# Epoch 158/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2859 - accuracy: 0.6222
# Epoch 159/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2747 - accuracy: 0.6222
# Epoch 160/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2632 - accuracy: 0.6222
# Epoch 161/500
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2535 - accuracy: 0.6222
# Epoch 162/500
# 2/2 [==============================] - 0s 18ms/step - loss: 1.2425 - accuracy: 0.6222
# Epoch 163/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2317 - accuracy: 0.6222
# Epoch 164/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2201 - accuracy: 0.6222
# Epoch 165/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2096 - accuracy: 0.6222
# Epoch 166/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2009 - accuracy: 0.6222
# Epoch 167/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1921 - accuracy: 0.6222
# Epoch 168/500
# 2/2 [==============================] - 0s 12ms/step - loss: 1.1815 - accuracy: 0.6222
# Epoch 169/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1718 - accuracy: 0.6222
# Epoch 170/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1602 - accuracy: 0.6222
# Epoch 171/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1500 - accuracy: 0.6222
# Epoch 172/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1400 - accuracy: 0.6222
# Epoch 173/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1295 - accuracy: 0.6222
# Epoch 174/500
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1201 - accuracy: 0.6222
# Epoch 175/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1109 - accuracy: 0.6222
# Epoch 176/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1013 - accuracy: 0.6222
# Epoch 177/500
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0907 - accuracy: 0.6444
# Epoch 178/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0814 - accuracy: 0.6444
# Epoch 179/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0720 - accuracy: 0.6444
# Epoch 180/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0626 - accuracy: 0.6444
# Epoch 181/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0528 - accuracy: 0.6444
# Epoch 182/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0433 - accuracy: 0.6444
# Epoch 183/500
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0341 - accuracy: 0.6444
# Epoch 184/500
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0242 - accuracy: 0.6444
# Epoch 185/500
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0148 - accuracy: 0.6444
# Epoch 186/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0070 - accuracy: 0.6889
# Epoch 187/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9977 - accuracy: 0.7111
# Epoch 188/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9883 - accuracy: 0.7333
# Epoch 189/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9794 - accuracy: 0.7333
# Epoch 190/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.7333
# Epoch 191/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9612 - accuracy: 0.7111
# Epoch 192/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9527 - accuracy: 0.7111
# Epoch 193/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9432 - accuracy: 0.7333
# Epoch 194/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9340 - accuracy: 0.7333
# Epoch 195/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9261 - accuracy: 0.7333
# Epoch 196/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9168 - accuracy: 0.7556
# Epoch 197/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9090 - accuracy: 0.7778
# Epoch 198/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9002 - accuracy: 0.7778
# Epoch 199/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8923 - accuracy: 0.7778
# Epoch 200/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8830 - accuracy: 0.7778
# Epoch 201/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8751 - accuracy: 0.7778
# Epoch 202/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8671 - accuracy: 0.7778
# Epoch 203/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8591 - accuracy: 0.7778
# Epoch 204/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8515 - accuracy: 0.7778
# Epoch 205/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8434 - accuracy: 0.7778
# Epoch 206/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8347 - accuracy: 0.7778
# Epoch 207/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8260 - accuracy: 0.8000
# Epoch 208/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8188 - accuracy: 0.8000
# Epoch 209/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8104 - accuracy: 0.8000
# Epoch 210/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8033 - accuracy: 0.8000
# Epoch 211/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7953 - accuracy: 0.8000
# Epoch 212/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7876 - accuracy: 0.8000
# Epoch 213/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7799 - accuracy: 0.8000
# Epoch 214/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7728 - accuracy: 0.8000
# Epoch 215/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7657 - accuracy: 0.8222
# Epoch 216/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7598 - accuracy: 0.8222
# Epoch 217/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7522 - accuracy: 0.8222
# Epoch 218/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7444 - accuracy: 0.8222
# Epoch 219/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7366 - accuracy: 0.8222
# Epoch 220/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7285 - accuracy: 0.8222
# Epoch 221/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7215 - accuracy: 0.8222
# Epoch 222/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7148 - accuracy: 0.8222
# Epoch 223/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7083 - accuracy: 0.8667
# Epoch 224/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7007 - accuracy: 0.8667
# Epoch 225/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6954 - accuracy: 0.8889
# Epoch 226/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.8889
# Epoch 227/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6803 - accuracy: 0.8889
# Epoch 228/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6740 - accuracy: 0.8889
# Epoch 229/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6682 - accuracy: 0.8667
# Epoch 230/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6613 - accuracy: 0.8667
# Epoch 231/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6546 - accuracy: 0.8889
# Epoch 232/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6483 - accuracy: 0.8889
# Epoch 233/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6402 - accuracy: 0.8889
# Epoch 234/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6345 - accuracy: 0.8889
# Epoch 235/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6273 - accuracy: 0.9111
# Epoch 236/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6221 - accuracy: 0.9333
# Epoch 237/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6170 - accuracy: 0.9333
# Epoch 238/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6115 - accuracy: 0.9333
# Epoch 239/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6046 - accuracy: 0.9333
# Epoch 240/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5980 - accuracy: 0.9333
# Epoch 241/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5915 - accuracy: 0.9333
# Epoch 242/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5858 - accuracy: 0.9333
# Epoch 243/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5811 - accuracy: 0.9333
# Epoch 244/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5752 - accuracy: 0.8889
# Epoch 245/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5695 - accuracy: 0.8889
# Epoch 246/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5634 - accuracy: 0.8889
# Epoch 247/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5580 - accuracy: 0.8889
# Epoch 248/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5519 - accuracy: 0.8889
# Epoch 249/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5467 - accuracy: 0.9333
# Epoch 250/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5409 - accuracy: 0.9333
# Epoch 251/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5351 - accuracy: 0.9333
# Epoch 252/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5296 - accuracy: 0.9333
# Epoch 253/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5240 - accuracy: 0.9333
# Epoch 254/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5190 - accuracy: 0.9333
# Epoch 255/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5139 - accuracy: 0.9333
# Epoch 256/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5096 - accuracy: 0.9556
# Epoch 257/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5053 - accuracy: 0.9556
# Epoch 258/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4999 - accuracy: 0.9778
# Epoch 259/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4947 - accuracy: 0.9778
# Epoch 260/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4909 - accuracy: 0.9778
# Epoch 261/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4846 - accuracy: 0.9778
# Epoch 262/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4799 - accuracy: 0.9778
# Epoch 263/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4750 - accuracy: 0.9778
# Epoch 264/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4696 - accuracy: 0.9556
# Epoch 265/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4652 - accuracy: 0.9556
# Epoch 266/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.9556
# Epoch 267/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4561 - accuracy: 0.9556
# Epoch 268/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4516 - accuracy: 0.9556
# Epoch 269/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4472 - accuracy: 0.9556
# Epoch 270/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4428 - accuracy: 0.9556
# Epoch 271/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4385 - accuracy: 0.9556
# Epoch 272/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4337 - accuracy: 0.9556
# Epoch 273/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4291 - accuracy: 0.9556
# Epoch 274/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.9556
# Epoch 275/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4215 - accuracy: 0.9556
# Epoch 276/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4181 - accuracy: 0.9556
# Epoch 277/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4139 - accuracy: 0.9556
# Epoch 278/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4085 - accuracy: 0.9556
# Epoch 279/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4053 - accuracy: 0.9556
# Epoch 280/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4012 - accuracy: 0.9556
# Epoch 281/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3965 - accuracy: 0.9778
# Epoch 282/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3926 - accuracy: 0.9556
# Epoch 283/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.9556
# Epoch 284/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3849 - accuracy: 0.9556
# Epoch 285/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3821 - accuracy: 0.9556
# Epoch 286/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3783 - accuracy: 0.9556
# Epoch 287/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3750 - accuracy: 0.9556
# Epoch 288/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3713 - accuracy: 0.9556
# Epoch 289/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3676 - accuracy: 0.9556
# Epoch 290/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3641 - accuracy: 0.9556
# Epoch 291/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3598 - accuracy: 0.9556
# Epoch 292/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3559 - accuracy: 0.9556
# Epoch 293/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3522 - accuracy: 0.9556
# Epoch 294/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3486 - accuracy: 0.9556
# Epoch 295/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3459 - accuracy: 0.9778
# Epoch 296/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3442 - accuracy: 0.9778
# Epoch 297/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3398 - accuracy: 0.9778
# Epoch 298/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3350 - accuracy: 0.9778
# Epoch 299/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3312 - accuracy: 0.9778
# Epoch 300/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3282 - accuracy: 0.9778
# Epoch 301/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3255 - accuracy: 0.9778
# Epoch 302/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3220 - accuracy: 0.9778
# Epoch 303/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3187 - accuracy: 0.9778
# Epoch 304/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3153 - accuracy: 0.9778
# Epoch 305/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3122 - accuracy: 0.9778
# Epoch 306/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3089 - accuracy: 0.9778
# Epoch 307/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3057 - accuracy: 0.9778
# Epoch 308/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3028 - accuracy: 0.9778
# Epoch 309/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2993 - accuracy: 0.9778
# Epoch 310/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2956 - accuracy: 0.9778
# Epoch 311/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2933 - accuracy: 0.9778
# Epoch 312/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2897 - accuracy: 0.9778
# Epoch 313/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2879 - accuracy: 0.9778
# Epoch 314/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2847 - accuracy: 0.9778
# Epoch 315/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2817 - accuracy: 0.9778
# Epoch 316/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2788 - accuracy: 0.9778
# Epoch 317/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2752 - accuracy: 0.9778
# Epoch 318/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2733 - accuracy: 0.9778
# Epoch 319/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.9778
# Epoch 320/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2665 - accuracy: 0.9778
# Epoch 321/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2648 - accuracy: 0.9778
# Epoch 322/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2621 - accuracy: 0.9778
# Epoch 323/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.9778
# Epoch 324/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2561 - accuracy: 0.9778
# Epoch 325/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2535 - accuracy: 0.9778
# Epoch 326/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2506 - accuracy: 0.9778
# Epoch 327/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.9778
# Epoch 328/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2459 - accuracy: 0.9778
# Epoch 329/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2433 - accuracy: 0.9778
# Epoch 330/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2412 - accuracy: 0.9778
# Epoch 331/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2394 - accuracy: 0.9778
# Epoch 332/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.9778
# Epoch 333/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2340 - accuracy: 0.9778
# Epoch 334/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2316 - accuracy: 0.9778
# Epoch 335/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2294 - accuracy: 0.9778
# Epoch 336/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2269 - accuracy: 0.9778
# Epoch 337/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2245 - accuracy: 1.0000
# Epoch 338/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2222 - accuracy: 1.0000
# Epoch 339/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2198 - accuracy: 1.0000
# Epoch 340/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2174 - accuracy: 0.9778
# Epoch 341/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2153 - accuracy: 0.9778
# Epoch 342/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2128 - accuracy: 0.9778
# Epoch 343/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2104 - accuracy: 0.9778
# Epoch 344/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2082 - accuracy: 0.9778
# Epoch 345/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9778
# Epoch 346/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2038 - accuracy: 0.9778
# Epoch 347/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2019 - accuracy: 0.9778
# Epoch 348/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1999 - accuracy: 0.9778
# Epoch 349/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1977 - accuracy: 0.9778
# Epoch 350/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1953 - accuracy: 1.0000
# Epoch 351/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1933 - accuracy: 0.9778
# Epoch 352/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1920 - accuracy: 0.9778
# Epoch 353/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1909 - accuracy: 0.9778
# Epoch 354/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1883 - accuracy: 1.0000
# Epoch 355/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1863 - accuracy: 1.0000
# Epoch 356/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1843 - accuracy: 1.0000
# Epoch 357/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1817 - accuracy: 1.0000
# Epoch 358/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1799 - accuracy: 1.0000
# Epoch 359/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1782 - accuracy: 1.0000
# Epoch 360/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1769 - accuracy: 0.9778
# Epoch 361/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1745 - accuracy: 1.0000
# Epoch 362/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1727 - accuracy: 1.0000
# Epoch 363/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1709 - accuracy: 1.0000
# Epoch 364/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1688 - accuracy: 1.0000
# Epoch 365/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1674 - accuracy: 1.0000
# Epoch 366/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1659 - accuracy: 1.0000
# Epoch 367/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1650 - accuracy: 1.0000
# Epoch 368/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1628 - accuracy: 1.0000
# Epoch 369/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1611 - accuracy: 1.0000
# Epoch 370/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1587 - accuracy: 1.0000
# Epoch 371/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1572 - accuracy: 1.0000
# Epoch 372/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1563 - accuracy: 1.0000
# Epoch 373/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1551 - accuracy: 1.0000
# Epoch 374/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1539 - accuracy: 1.0000
# Epoch 375/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1518 - accuracy: 1.0000
# Epoch 376/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1501 - accuracy: 1.0000
# Epoch 377/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1483 - accuracy: 1.0000
# Epoch 378/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1471 - accuracy: 1.0000
# Epoch 379/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1460 - accuracy: 1.0000
# Epoch 380/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1444 - accuracy: 1.0000
# Epoch 381/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1430 - accuracy: 1.0000
# Epoch 382/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1411 - accuracy: 1.0000
# Epoch 383/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1397 - accuracy: 1.0000
# Epoch 384/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1381 - accuracy: 1.0000
# Epoch 385/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1372 - accuracy: 1.0000
# Epoch 386/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1360 - accuracy: 1.0000
# Epoch 387/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1347 - accuracy: 1.0000
# Epoch 388/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1333 - accuracy: 1.0000
# Epoch 389/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1321 - accuracy: 1.0000
# Epoch 390/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1309 - accuracy: 1.0000
# Epoch 391/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 1.0000
# Epoch 392/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1281 - accuracy: 1.0000
# Epoch 393/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1265 - accuracy: 1.0000
# Epoch 394/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1253 - accuracy: 1.0000
# Epoch 395/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1246 - accuracy: 1.0000
# Epoch 396/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1233 - accuracy: 1.0000
# Epoch 397/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1218 - accuracy: 1.0000
# Epoch 398/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1205 - accuracy: 1.0000
# Epoch 399/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1192 - accuracy: 1.0000
# Epoch 400/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1182 - accuracy: 1.0000
# Epoch 401/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1172 - accuracy: 1.0000
# Epoch 402/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1162 - accuracy: 1.0000
# Epoch 403/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1154 - accuracy: 1.0000
# Epoch 404/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1139 - accuracy: 1.0000
# Epoch 405/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1130 - accuracy: 1.0000
# Epoch 406/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1118 - accuracy: 1.0000
# Epoch 407/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1106 - accuracy: 1.0000
# Epoch 408/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1098 - accuracy: 1.0000
# Epoch 409/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1087 - accuracy: 1.0000
# Epoch 410/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1074 - accuracy: 1.0000
# Epoch 411/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1065 - accuracy: 1.0000
# Epoch 412/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1053 - accuracy: 1.0000
# Epoch 413/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1043 - accuracy: 1.0000
# Epoch 414/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1033 - accuracy: 1.0000
# Epoch 415/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1022 - accuracy: 1.0000
# Epoch 416/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1013 - accuracy: 1.0000
# Epoch 417/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1005 - accuracy: 1.0000
# Epoch 418/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0993 - accuracy: 1.0000
# Epoch 419/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0987 - accuracy: 1.0000
# Epoch 420/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0979 - accuracy: 1.0000
# Epoch 421/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0968 - accuracy: 1.0000
# Epoch 422/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0960 - accuracy: 1.0000
# Epoch 423/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 1.0000
# Epoch 424/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 425/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0930 - accuracy: 1.0000
# Epoch 426/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0923 - accuracy: 1.0000
# Epoch 427/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 428/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 429/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0895 - accuracy: 1.0000
# Epoch 430/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0885 - accuracy: 1.0000
# Epoch 431/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0883 - accuracy: 1.0000
# Epoch 432/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0872 - accuracy: 1.0000
# Epoch 433/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 1.0000
# Epoch 434/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0862 - accuracy: 1.0000
# Epoch 435/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0851 - accuracy: 1.0000
# Epoch 436/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0841 - accuracy: 1.0000
# Epoch 437/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0833 - accuracy: 1.0000
# Epoch 438/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0825 - accuracy: 1.0000
# Epoch 439/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0817 - accuracy: 1.0000
# Epoch 440/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0809 - accuracy: 1.0000
# Epoch 441/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 1.0000
# Epoch 442/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0794 - accuracy: 1.0000
# Epoch 443/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0786 - accuracy: 1.0000
# Epoch 444/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0779 - accuracy: 1.0000
# Epoch 445/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0773 - accuracy: 1.0000
# Epoch 446/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 447/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 448/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 1.0000
# Epoch 449/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 1.0000
# Epoch 450/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0740 - accuracy: 1.0000
# Epoch 451/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0733 - accuracy: 1.0000
# Epoch 452/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0724 - accuracy: 1.0000
# Epoch 453/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0719 - accuracy: 1.0000
# Epoch 454/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 455/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 456/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0699 - accuracy: 1.0000
# Epoch 457/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 458/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 459/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0683 - accuracy: 1.0000
# Epoch 460/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0678 - accuracy: 1.0000
# Epoch 461/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0672 - accuracy: 1.0000
# Epoch 462/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 463/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 464/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 465/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 1.0000
# Epoch 466/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 467/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0638 - accuracy: 1.0000
# Epoch 468/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0634 - accuracy: 1.0000
# Epoch 469/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0626 - accuracy: 1.0000
# Epoch 470/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0620 - accuracy: 1.0000
# Epoch 471/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0616 - accuracy: 1.0000
# Epoch 472/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 473/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 474/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 475/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0592 - accuracy: 1.0000
# Epoch 476/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 477/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 478/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 479/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 480/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 481/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 482/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 483/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 484/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0548 - accuracy: 1.0000
# Epoch 485/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0544 - accuracy: 1.0000
# Epoch 486/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0540 - accuracy: 1.0000
# Epoch 487/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 488/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0531 - accuracy: 1.0000
# Epoch 489/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 490/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 491/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 492/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 493/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 494/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 495/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 496/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 497/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 498/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 499/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 500/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0483 - accuracy: 1.0000

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model/assets

# %%
def webscraper(x):
  from urllib.request import Request, urlopen
  from bs4 import BeautifulSoup
  import requests
  from random import randint

  #x = inp

  root = "https://www.google.com"
  link = "https://www.google.com/search?q=top+10+{}+movies&oq=top+&aqs=chrome.0.69i59l3j69i57j69i60l4.651j0j4&sourceid=chrome&ie=UTF-8".format(x)
  results = []

  req = Request(link, headers = {"User-Agent": "Mozilla/5.0"})
  webpage = urlopen(req).read()
  with requests.Session() as c:
    soup = BeautifulSoup(webpage, "html5lib")
    #print(soup)
    for item in soup.find_all('div', attrs = {"class": "RWuggc"}):
      results.append(item)

  titles = []
  for word in results:
    for j in word:
      for i in j:
        for p in i:
          titles.append(p)

  end_of_titles = len(titles)
  movie_index = randint(0, end_of_titles )
  movie_index_end = movie_index + 1
  return(titles[movie_index:movie_index_end])

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

with open("intents.json") as file:
    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])

        if tag == "thanks":
            print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))
            break
        if tag == "genres":
          print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))
          print(webscraper(inp))
        if tag == "another":
          print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))
          print(webscraper(inp))
          



        for i in data['intents']:
            if i['tag'] == tag:
                print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))

        # print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# User: I would like to watch a movie
# ChatBot: What genre would you like to watch?
# User: action
# ChatBot: Hold on one second please
# ['2018']
# ChatBot: I'll check what movie you'd maybe like to watch
# User: I watched that one
# ChatBot: Give me one second
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-13-1cc17d087955> in <module>()
#      60
#      61 print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
# ---> 62 chat()
#
# <ipython-input-13-1cc17d087955> in chat()
#      48         if tag == "another":
#      49           print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))
# ---> 50           print(webscraper(inp))
#      51
#      52
#
# <ipython-input-10-db0184826177> in webscraper(x)
#      12
#      13   req = Request(link, headers = {"User-Agent": "Mozilla/5.0"})
# ---> 14   webpage = urlopen(req).read()
#      15   with requests.Session() as c:
#      16     soup = BeautifulSoup(webpage, "html5lib")
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             try:
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1279                 encode_chunked=False):
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#    1283     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1290             skips['skip_accept_encoding'] = 1
#    1291
# -> 1292         self.putrequest(method, url, **skips)
#    1293
#    1294         # chunked encoding will happen if HTTP/1.1 is used and either
#
# /usr/lib/python3.7/http/client.py in putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1124
#    1125         url = url or '/'
# -> 1126         self._validate_path(url)
#    1127
#    1128         request = '%s %s %s' % (method, url, self._http_vsn_str)
#
# /usr/lib/python3.7/http/client.py in _validate_path(self, url)
#    1224         match = _contains_disallowed_url_pchar_re.search(url)
#    1225         if match:
# -> 1226             raise InvalidURL(f"URL can't contain control characters. {url!r} "
#    1227                              f"(found at least {match.group()!r})")
#    1228
#
# InvalidURL: URL can't contain control characters. '/search?q=top+10+I watched that one+movies&oq=top+&aqs=chrome.0.69i59l3j69i57j69i60l4.651j0j4&sourceid=chrome&ie=UTF-8' (found at least ' ')

# %%
webscraper("action")

# %%
titles = []
for word in results:
  for j in word:
    for i in j:
      for p in i:
        titles.append(p)

print(titles)

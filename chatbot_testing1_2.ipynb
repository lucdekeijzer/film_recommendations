# %% [markdown]
# <a href="https://colab.research.google.com/github/lucdekeijzer/film_recommendations/blob/main/chatbot_testing1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorama
# !pip install scikit_learn
# !pip install Flask
# !pip install beautifulsoup4
# !pip install bs4
# !pip install googletrans==4.0.0rc1
# Out:
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.4
# Requirement already satisfied: scikit_learn in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (3.0.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.19.5)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Collecting googletrans==4.0.0rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.0 MB/s
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2.10)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2021.10.8)
# Collecting hstspreload
#   Downloading hstspreload-2021.11.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 12.5 MB/s
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (3.0.4)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.7 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.9 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17415 sha256=629431d78627284b0ffd5f1e39fcf61283bc3877aa684e0d23a57df7fa2f3e07
#   Stored in directory: /root/.cache/pip/wheels/43/34/00/4fe71786ea6d12314b29037620c36d857e5d104ac2748bf82a
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
import googletrans
from googletrans import Translator
import requests
import pandas as pd

# %%
#with open('intents.json') as file:
    #data = json.load(file)

data = pd.read_json("https://raw.githubusercontent.com/lucdekeijzer/film_recommendations/main/intents.json")
 

training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 16,714
# Trainable params: 16,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 5ms/step - loss: 2.3020 - accuracy: 0.0938
# Epoch 2/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2992 - accuracy: 0.1562
# Epoch 3/500
# 3/3 [==============================] - 0s 12ms/step - loss: 2.2970 - accuracy: 0.1354
# Epoch 4/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2947 - accuracy: 0.1458
# Epoch 5/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2927 - accuracy: 0.1458
# Epoch 6/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2904 - accuracy: 0.1458
# Epoch 7/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2881 - accuracy: 0.1354
# Epoch 8/500
# 3/3 [==============================] - 0s 9ms/step - loss: 2.2856 - accuracy: 0.1354
# Epoch 9/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2827 - accuracy: 0.1354
# Epoch 10/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2802 - accuracy: 0.1354
# Epoch 11/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2774 - accuracy: 0.1354
# Epoch 12/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2742 - accuracy: 0.1354
# Epoch 13/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2712 - accuracy: 0.1354
# Epoch 14/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2677 - accuracy: 0.1354
# Epoch 15/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2645 - accuracy: 0.1354
# Epoch 16/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2612 - accuracy: 0.1354
# Epoch 17/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2575 - accuracy: 0.1354
# Epoch 18/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2538 - accuracy: 0.1354
# Epoch 19/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2501 - accuracy: 0.1354
# Epoch 20/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2462 - accuracy: 0.1354
# Epoch 21/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2422 - accuracy: 0.1354
# Epoch 22/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2386 - accuracy: 0.1354
# Epoch 23/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2338 - accuracy: 0.1458
# Epoch 24/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2293 - accuracy: 0.1771
# Epoch 25/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2257 - accuracy: 0.1667
# Epoch 26/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2211 - accuracy: 0.1771
# Epoch 27/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2171 - accuracy: 0.3333
# Epoch 28/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2125 - accuracy: 0.3438
# Epoch 29/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2081 - accuracy: 0.3229
# Epoch 30/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2039 - accuracy: 0.3125
# Epoch 31/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2020 - accuracy: 0.3021
# Epoch 32/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1956 - accuracy: 0.2917
# Epoch 33/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1916 - accuracy: 0.2917
# Epoch 34/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1873 - accuracy: 0.2917
# Epoch 35/500
# 3/3 [==============================] - 0s 8ms/step - loss: 2.1829 - accuracy: 0.2917
# Epoch 36/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1797 - accuracy: 0.2917
# Epoch 37/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1763 - accuracy: 0.2812
# Epoch 38/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1726 - accuracy: 0.2500
# Epoch 39/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1686 - accuracy: 0.2396
# Epoch 40/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1661 - accuracy: 0.2396
# Epoch 41/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1619 - accuracy: 0.2292
# Epoch 42/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1593 - accuracy: 0.2292
# Epoch 43/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1556 - accuracy: 0.2292
# Epoch 44/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1523 - accuracy: 0.2292
# Epoch 45/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1492 - accuracy: 0.2292
# Epoch 46/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1458 - accuracy: 0.2292
# Epoch 47/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1432 - accuracy: 0.2292
# Epoch 48/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1397 - accuracy: 0.2292
# Epoch 49/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1368 - accuracy: 0.2292
# Epoch 50/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1338 - accuracy: 0.2292
# Epoch 51/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1302 - accuracy: 0.2292
# Epoch 52/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1273 - accuracy: 0.2292
# Epoch 53/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1240 - accuracy: 0.2292
# Epoch 54/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1205 - accuracy: 0.2292
# Epoch 55/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1171 - accuracy: 0.2292
# Epoch 56/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1136 - accuracy: 0.2396
# Epoch 57/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1101 - accuracy: 0.2396
# Epoch 58/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1063 - accuracy: 0.2396
# Epoch 59/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1024 - accuracy: 0.2396
# Epoch 60/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0989 - accuracy: 0.2500
# Epoch 61/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0946 - accuracy: 0.2604
# Epoch 62/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0903 - accuracy: 0.2708
# Epoch 63/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0862 - accuracy: 0.2708
# Epoch 64/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0814 - accuracy: 0.2812
# Epoch 65/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0768 - accuracy: 0.2812
# Epoch 66/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0724 - accuracy: 0.2917
# Epoch 67/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0670 - accuracy: 0.2917
# Epoch 68/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0625 - accuracy: 0.2917
# Epoch 69/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0566 - accuracy: 0.2917
# Epoch 70/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0517 - accuracy: 0.2917
# Epoch 71/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0463 - accuracy: 0.2917
# Epoch 72/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0404 - accuracy: 0.2917
# Epoch 73/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0338 - accuracy: 0.2917
# Epoch 74/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0274 - accuracy: 0.2917
# Epoch 75/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0214 - accuracy: 0.2917
# Epoch 76/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0146 - accuracy: 0.2917
# Epoch 77/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0075 - accuracy: 0.2917
# Epoch 78/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0012 - accuracy: 0.2917
# Epoch 79/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9935 - accuracy: 0.2917
# Epoch 80/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.9862 - accuracy: 0.2917
# Epoch 81/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9785 - accuracy: 0.3125
# Epoch 82/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9707 - accuracy: 0.3021
# Epoch 83/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9629 - accuracy: 0.3021
# Epoch 84/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9551 - accuracy: 0.3125
# Epoch 85/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9459 - accuracy: 0.3021
# Epoch 86/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9369 - accuracy: 0.3021
# Epoch 87/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9283 - accuracy: 0.3229
# Epoch 88/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9194 - accuracy: 0.3021
# Epoch 89/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9109 - accuracy: 0.3021
# Epoch 90/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9014 - accuracy: 0.3021
# Epoch 91/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8926 - accuracy: 0.3125
# Epoch 92/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8827 - accuracy: 0.3333
# Epoch 93/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8738 - accuracy: 0.3438
# Epoch 94/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8642 - accuracy: 0.3438
# Epoch 95/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8546 - accuracy: 0.3646
# Epoch 96/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8454 - accuracy: 0.3750
# Epoch 97/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8356 - accuracy: 0.3750
# Epoch 98/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8260 - accuracy: 0.3854
# Epoch 99/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8161 - accuracy: 0.3854
# Epoch 100/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8066 - accuracy: 0.3958
# Epoch 101/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7963 - accuracy: 0.3958
# Epoch 102/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7865 - accuracy: 0.3958
# Epoch 103/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7764 - accuracy: 0.4062
# Epoch 104/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7665 - accuracy: 0.4167
# Epoch 105/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7559 - accuracy: 0.4167
# Epoch 106/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7457 - accuracy: 0.4167
# Epoch 107/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7353 - accuracy: 0.4167
# Epoch 108/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7239 - accuracy: 0.4271
# Epoch 109/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7129 - accuracy: 0.4271
# Epoch 110/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7011 - accuracy: 0.4375
# Epoch 111/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6899 - accuracy: 0.4375
# Epoch 112/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6785 - accuracy: 0.4479
# Epoch 113/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6677 - accuracy: 0.4375
# Epoch 114/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6553 - accuracy: 0.4479
# Epoch 115/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6439 - accuracy: 0.4479
# Epoch 116/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6328 - accuracy: 0.4583
# Epoch 117/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.6207 - accuracy: 0.4583
# Epoch 118/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6101 - accuracy: 0.4479
# Epoch 119/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5966 - accuracy: 0.4375
# Epoch 120/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5852 - accuracy: 0.4375
# Epoch 121/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5733 - accuracy: 0.4375
# Epoch 122/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5605 - accuracy: 0.4375
# Epoch 123/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5481 - accuracy: 0.4375
# Epoch 124/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5353 - accuracy: 0.4375
# Epoch 125/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5220 - accuracy: 0.4375
# Epoch 126/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5091 - accuracy: 0.4375
# Epoch 127/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4958 - accuracy: 0.4375
# Epoch 128/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4826 - accuracy: 0.4375
# Epoch 129/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4686 - accuracy: 0.4375
# Epoch 130/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4551 - accuracy: 0.4375
# Epoch 131/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4405 - accuracy: 0.4375
# Epoch 132/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4262 - accuracy: 0.4375
# Epoch 133/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4119 - accuracy: 0.4479
# Epoch 134/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3985 - accuracy: 0.4479
# Epoch 135/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3822 - accuracy: 0.4583
# Epoch 136/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3682 - accuracy: 0.4583
# Epoch 137/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3548 - accuracy: 0.4583
# Epoch 138/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3388 - accuracy: 0.4688
# Epoch 139/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3252 - accuracy: 0.4688
# Epoch 140/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3114 - accuracy: 0.4688
# Epoch 141/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2962 - accuracy: 0.4688
# Epoch 142/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2824 - accuracy: 0.4792
# Epoch 143/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2680 - accuracy: 0.4792
# Epoch 144/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2540 - accuracy: 0.4792
# Epoch 145/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2401 - accuracy: 0.4792
# Epoch 146/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2270 - accuracy: 0.4792
# Epoch 147/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2128 - accuracy: 0.4792
# Epoch 148/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1992 - accuracy: 0.4792
# Epoch 149/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1858 - accuracy: 0.4896
# Epoch 150/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1731 - accuracy: 0.4896
# Epoch 151/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1588 - accuracy: 0.5312
# Epoch 152/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1465 - accuracy: 0.5729
# Epoch 153/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1328 - accuracy: 0.5833
# Epoch 154/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.1192 - accuracy: 0.6146
# Epoch 155/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1069 - accuracy: 0.6146
# Epoch 156/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0936 - accuracy: 0.6146
# Epoch 157/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0806 - accuracy: 0.6146
# Epoch 158/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0679 - accuracy: 0.6042
# Epoch 159/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0562 - accuracy: 0.6042
# Epoch 160/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0435 - accuracy: 0.6042
# Epoch 161/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0304 - accuracy: 0.6042
# Epoch 162/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0177 - accuracy: 0.6042
# Epoch 163/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0055 - accuracy: 0.6042
# Epoch 164/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9928 - accuracy: 0.6250
# Epoch 165/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9800 - accuracy: 0.6354
# Epoch 166/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9674 - accuracy: 0.6354
# Epoch 167/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9558 - accuracy: 0.6562
# Epoch 168/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9426 - accuracy: 0.6562
# Epoch 169/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9299 - accuracy: 0.6667
# Epoch 170/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9171 - accuracy: 0.6875
# Epoch 171/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9042 - accuracy: 0.6979
# Epoch 172/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8922 - accuracy: 0.6979
# Epoch 173/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8805 - accuracy: 0.7292
# Epoch 174/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8684 - accuracy: 0.7292
# Epoch 175/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8570 - accuracy: 0.7292
# Epoch 176/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8447 - accuracy: 0.7188
# Epoch 177/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8334 - accuracy: 0.7188
# Epoch 178/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8238 - accuracy: 0.7083
# Epoch 179/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8116 - accuracy: 0.7188
# Epoch 180/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8001 - accuracy: 0.7292
# Epoch 181/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7911 - accuracy: 0.7708
# Epoch 182/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7794 - accuracy: 0.7812
# Epoch 183/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7700 - accuracy: 0.7708
# Epoch 184/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7582 - accuracy: 0.7708
# Epoch 185/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7477 - accuracy: 0.7708
# Epoch 186/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7368 - accuracy: 0.7917
# Epoch 187/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7262 - accuracy: 0.7917
# Epoch 188/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7165 - accuracy: 0.8021
# Epoch 189/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7062 - accuracy: 0.8125
# Epoch 190/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6953 - accuracy: 0.8229
# Epoch 191/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.8229
# Epoch 192/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6761 - accuracy: 0.8229
# Epoch 193/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6653 - accuracy: 0.8125
# Epoch 194/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6553 - accuracy: 0.8229
# Epoch 195/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6468 - accuracy: 0.8229
# Epoch 196/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6381 - accuracy: 0.8229
# Epoch 197/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6287 - accuracy: 0.8229
# Epoch 198/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6195 - accuracy: 0.8229
# Epoch 199/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6109 - accuracy: 0.8229
# Epoch 200/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6025 - accuracy: 0.8229
# Epoch 201/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5950 - accuracy: 0.8229
# Epoch 202/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5876 - accuracy: 0.8229
# Epoch 203/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5790 - accuracy: 0.8229
# Epoch 204/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5719 - accuracy: 0.8229
# Epoch 205/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5647 - accuracy: 0.8229
# Epoch 206/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5568 - accuracy: 0.8229
# Epoch 207/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5496 - accuracy: 0.8229
# Epoch 208/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5428 - accuracy: 0.8229
# Epoch 209/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5356 - accuracy: 0.8229
# Epoch 210/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5292 - accuracy: 0.8229
# Epoch 211/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5225 - accuracy: 0.8333
# Epoch 212/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5157 - accuracy: 0.8438
# Epoch 213/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5096 - accuracy: 0.8438
# Epoch 214/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5027 - accuracy: 0.8438
# Epoch 215/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4973 - accuracy: 0.8438
# Epoch 216/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4912 - accuracy: 0.8438
# Epoch 217/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4855 - accuracy: 0.8438
# Epoch 218/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4796 - accuracy: 0.8438
# Epoch 219/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4735 - accuracy: 0.8542
# Epoch 220/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4684 - accuracy: 0.8542
# Epoch 221/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4630 - accuracy: 0.8542
# Epoch 222/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4577 - accuracy: 0.8542
# Epoch 223/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.8542
# Epoch 224/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4474 - accuracy: 0.8542
# Epoch 225/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4421 - accuracy: 0.8646
# Epoch 226/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4374 - accuracy: 0.8646
# Epoch 227/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4316 - accuracy: 0.8646
# Epoch 228/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4266 - accuracy: 0.8646
# Epoch 229/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4213 - accuracy: 0.8646
# Epoch 230/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4170 - accuracy: 0.8646
# Epoch 231/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4124 - accuracy: 0.8542
# Epoch 232/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4073 - accuracy: 0.8750
# Epoch 233/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4029 - accuracy: 0.8750
# Epoch 234/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3995 - accuracy: 0.8750
# Epoch 235/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3939 - accuracy: 0.8854
# Epoch 236/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3891 - accuracy: 0.8958
# Epoch 237/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3845 - accuracy: 0.8958
# Epoch 238/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3803 - accuracy: 0.9062
# Epoch 239/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3764 - accuracy: 0.9167
# Epoch 240/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3721 - accuracy: 0.9375
# Epoch 241/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.9583
# Epoch 242/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3629 - accuracy: 0.9583
# Epoch 243/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3588 - accuracy: 0.9583
# Epoch 244/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3551 - accuracy: 0.9583
# Epoch 245/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3512 - accuracy: 0.9583
# Epoch 246/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3465 - accuracy: 0.9583
# Epoch 247/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3425 - accuracy: 0.9583
# Epoch 248/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3385 - accuracy: 0.9583
# Epoch 249/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3354 - accuracy: 0.9583
# Epoch 250/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3310 - accuracy: 0.9583
# Epoch 251/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3269 - accuracy: 0.9583
# Epoch 252/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3237 - accuracy: 0.9583
# Epoch 253/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3199 - accuracy: 0.9583
# Epoch 254/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3149 - accuracy: 0.9583
# Epoch 255/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3113 - accuracy: 0.9583
# Epoch 256/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3078 - accuracy: 0.9583
# Epoch 257/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3046 - accuracy: 0.9583
# Epoch 258/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3004 - accuracy: 0.9583
# Epoch 259/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2965 - accuracy: 0.9583
# Epoch 260/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2940 - accuracy: 0.9583
# Epoch 261/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2893 - accuracy: 0.9583
# Epoch 262/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2867 - accuracy: 0.9583
# Epoch 263/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2836 - accuracy: 0.9583
# Epoch 264/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.9583
# Epoch 265/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2758 - accuracy: 0.9583
# Epoch 266/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2726 - accuracy: 0.9583
# Epoch 267/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2691 - accuracy: 0.9583
# Epoch 268/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2661 - accuracy: 0.9583
# Epoch 269/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2628 - accuracy: 0.9583
# Epoch 270/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2601 - accuracy: 0.9479
# Epoch 271/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2562 - accuracy: 0.9479
# Epoch 272/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2538 - accuracy: 0.9583
# Epoch 273/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2503 - accuracy: 0.9583
# Epoch 274/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2473 - accuracy: 0.9479
# Epoch 275/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.9479
# Epoch 276/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2404 - accuracy: 0.9583
# Epoch 277/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2378 - accuracy: 0.9583
# Epoch 278/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2345 - accuracy: 0.9583
# Epoch 279/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2317 - accuracy: 0.9583
# Epoch 280/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2288 - accuracy: 0.9583
# Epoch 281/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2261 - accuracy: 0.9479
# Epoch 282/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2227 - accuracy: 0.9583
# Epoch 283/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2202 - accuracy: 0.9583
# Epoch 284/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2177 - accuracy: 0.9583
# Epoch 285/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2155 - accuracy: 0.9583
# Epoch 286/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2125 - accuracy: 0.9688
# Epoch 287/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2098 - accuracy: 0.9688
# Epoch 288/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2069 - accuracy: 0.9688
# Epoch 289/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2044 - accuracy: 0.9688
# Epoch 290/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2022 - accuracy: 0.9688
# Epoch 291/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1999 - accuracy: 0.9688
# Epoch 292/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1970 - accuracy: 0.9688
# Epoch 293/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1949 - accuracy: 0.9688
# Epoch 294/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1922 - accuracy: 0.9792
# Epoch 295/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1898 - accuracy: 0.9688
# Epoch 296/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1879 - accuracy: 0.9792
# Epoch 297/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1848 - accuracy: 0.9792
# Epoch 298/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1846 - accuracy: 0.9792
# Epoch 299/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1808 - accuracy: 0.9792
# Epoch 300/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1786 - accuracy: 0.9688
# Epoch 301/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1767 - accuracy: 0.9792
# Epoch 302/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1743 - accuracy: 0.9792
# Epoch 303/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1723 - accuracy: 0.9792
# Epoch 304/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1705 - accuracy: 0.9688
# Epoch 305/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1683 - accuracy: 0.9792
# Epoch 306/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1657 - accuracy: 0.9792
# Epoch 307/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1634 - accuracy: 0.9792
# Epoch 308/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1617 - accuracy: 0.9792
# Epoch 309/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1596 - accuracy: 0.9792
# Epoch 310/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1576 - accuracy: 0.9792
# Epoch 311/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1567 - accuracy: 0.9792
# Epoch 312/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1538 - accuracy: 0.9792
# Epoch 313/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1519 - accuracy: 0.9792
# Epoch 314/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1506 - accuracy: 0.9792
# Epoch 315/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1487 - accuracy: 0.9792
# Epoch 316/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1472 - accuracy: 0.9688
# Epoch 317/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9792
# Epoch 318/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1433 - accuracy: 0.9792
# Epoch 319/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1430 - accuracy: 0.9688
# Epoch 320/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1412 - accuracy: 0.9688
# Epoch 321/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1408 - accuracy: 0.9792
# Epoch 322/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.9792
# Epoch 323/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1368 - accuracy: 0.9792
# Epoch 324/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1346 - accuracy: 0.9792
# Epoch 325/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1324 - accuracy: 0.9792
# Epoch 326/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.9792
# Epoch 327/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1299 - accuracy: 0.9792
# Epoch 328/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1287 - accuracy: 0.9792
# Epoch 329/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1266 - accuracy: 0.9792
# Epoch 330/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1259 - accuracy: 0.9688
# Epoch 331/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1244 - accuracy: 0.9792
# Epoch 332/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1228 - accuracy: 0.9792
# Epoch 333/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1216 - accuracy: 0.9792
# Epoch 334/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1205 - accuracy: 0.9792
# Epoch 335/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1193 - accuracy: 0.9792
# Epoch 336/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1185 - accuracy: 0.9688
# Epoch 337/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1166 - accuracy: 0.9792
# Epoch 338/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9688
# Epoch 339/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1149 - accuracy: 0.9792
# Epoch 340/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1129 - accuracy: 0.9792
# Epoch 341/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1120 - accuracy: 0.9792
# Epoch 342/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1110 - accuracy: 0.9688
# Epoch 343/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9688
# Epoch 344/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1103 - accuracy: 0.9688
# Epoch 345/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1077 - accuracy: 0.9792
# Epoch 346/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1069 - accuracy: 0.9792
# Epoch 347/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1066 - accuracy: 0.9688
# Epoch 348/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1047 - accuracy: 0.9792
# Epoch 349/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1039 - accuracy: 0.9688
# Epoch 350/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1028 - accuracy: 0.9792
# Epoch 351/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1022 - accuracy: 0.9688
# Epoch 352/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9792
# Epoch 353/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9792
# Epoch 354/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0997 - accuracy: 0.9688
# Epoch 355/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0983 - accuracy: 0.9792
# Epoch 356/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0973 - accuracy: 0.9792
# Epoch 357/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0966 - accuracy: 0.9792
# Epoch 358/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0964 - accuracy: 0.9792
# Epoch 359/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9792
# Epoch 360/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0943 - accuracy: 0.9792
# Epoch 361/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0935 - accuracy: 0.9792
# Epoch 362/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0929 - accuracy: 0.9688
# Epoch 363/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9792
# Epoch 364/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0912 - accuracy: 0.9792
# Epoch 365/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9792
# Epoch 366/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0900 - accuracy: 0.9792
# Epoch 367/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0890 - accuracy: 0.9792
# Epoch 368/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0888 - accuracy: 0.9792
# Epoch 369/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 0.9792
# Epoch 370/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.9792
# Epoch 371/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0864 - accuracy: 0.9792
# Epoch 372/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0861 - accuracy: 0.9688
# Epoch 373/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0859 - accuracy: 0.9792
# Epoch 374/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0856 - accuracy: 0.9688
# Epoch 375/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0843 - accuracy: 0.9688
# Epoch 376/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9688
# Epoch 377/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0827 - accuracy: 0.9792
# Epoch 378/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0820 - accuracy: 0.9792
# Epoch 379/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0817 - accuracy: 0.9688
# Epoch 380/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0810 - accuracy: 0.9792
# Epoch 381/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0802 - accuracy: 0.9792
# Epoch 382/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9792
# Epoch 383/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0797 - accuracy: 0.9792
# Epoch 384/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0792 - accuracy: 0.9792
# Epoch 385/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9792
# Epoch 386/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9792
# Epoch 387/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9792
# Epoch 388/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9688
# Epoch 389/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 0.9792
# Epoch 390/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9792
# Epoch 391/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9688
# Epoch 392/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9792
# Epoch 393/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9792
# Epoch 394/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0743 - accuracy: 0.9688
# Epoch 395/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0737 - accuracy: 0.9792
# Epoch 396/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0731 - accuracy: 0.9792
# Epoch 397/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0731 - accuracy: 0.9792
# Epoch 398/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0725 - accuracy: 0.9792
# Epoch 399/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.9792
# Epoch 400/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0719 - accuracy: 0.9688
# Epoch 401/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9792
# Epoch 402/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0711 - accuracy: 0.9688
# Epoch 403/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.9792
# Epoch 404/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0700 - accuracy: 0.9792
# Epoch 405/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0709 - accuracy: 0.9792
# Epoch 406/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0697 - accuracy: 0.9792
# Epoch 407/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0686 - accuracy: 0.9688
# Epoch 408/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0685 - accuracy: 0.9792
# Epoch 409/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 0.9792
# Epoch 410/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0692 - accuracy: 0.9792
# Epoch 411/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0673 - accuracy: 0.9792
# Epoch 412/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0667 - accuracy: 0.9792
# Epoch 413/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0664 - accuracy: 0.9792
# Epoch 414/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0667 - accuracy: 0.9688
# Epoch 415/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0657 - accuracy: 0.9792
# Epoch 416/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0658 - accuracy: 0.9792
# Epoch 417/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0653 - accuracy: 0.9688
# Epoch 418/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0651 - accuracy: 0.9792
# Epoch 419/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9688
# Epoch 420/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9792
# Epoch 421/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9792
# Epoch 422/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9792
# Epoch 423/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0639 - accuracy: 0.9792
# Epoch 424/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0632 - accuracy: 0.9792
# Epoch 425/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0631 - accuracy: 0.9792
# Epoch 426/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 0.9688
# Epoch 427/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0617 - accuracy: 0.9792
# Epoch 428/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9792
# Epoch 429/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0611 - accuracy: 0.9792
# Epoch 430/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0609 - accuracy: 0.9792
# Epoch 431/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 0.9792
# Epoch 432/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9792
# Epoch 433/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0602 - accuracy: 0.9792
# Epoch 434/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0602 - accuracy: 0.9688
# Epoch 435/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9688
# Epoch 436/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 0.9792
# Epoch 437/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9688
# Epoch 438/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9792
# Epoch 439/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0583 - accuracy: 0.9688
# Epoch 440/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0580 - accuracy: 0.9792
# Epoch 441/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9792
# Epoch 442/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.9792
# Epoch 443/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0579 - accuracy: 0.9688
# Epoch 444/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9688
# Epoch 445/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0579 - accuracy: 0.9688
# Epoch 446/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0569 - accuracy: 0.9792
# Epoch 447/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0560 - accuracy: 0.9792
# Epoch 448/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9792
# Epoch 449/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9792
# Epoch 450/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0557 - accuracy: 0.9792
# Epoch 451/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9792
# Epoch 452/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0550 - accuracy: 0.9688
# Epoch 453/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9792
# Epoch 454/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9792
# Epoch 455/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0543 - accuracy: 0.9688
# Epoch 456/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9792
# Epoch 457/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9792
# Epoch 458/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0538 - accuracy: 0.9688
# Epoch 459/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0553 - accuracy: 0.9688
# Epoch 460/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0531 - accuracy: 0.9792
# Epoch 461/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 0.9792
# Epoch 462/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0538 - accuracy: 0.9688
# Epoch 463/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9792
# Epoch 464/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9792
# Epoch 465/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0524 - accuracy: 0.9792
# Epoch 466/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0519 - accuracy: 0.9792
# Epoch 467/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0514 - accuracy: 0.9792
# Epoch 468/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0518 - accuracy: 0.9792
# Epoch 469/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0513 - accuracy: 0.9792
# Epoch 470/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0513 - accuracy: 0.9792
# Epoch 471/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0512 - accuracy: 0.9792
# Epoch 472/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0510 - accuracy: 0.9792
# Epoch 473/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 0.9792
# Epoch 474/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 0.9792
# Epoch 475/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9688
# Epoch 476/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9792
# Epoch 477/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9792
# Epoch 478/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 0.9688
# Epoch 479/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 0.9792
# Epoch 480/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0495 - accuracy: 0.9792
# Epoch 481/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9688
# Epoch 482/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 0.9688
# Epoch 483/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9792
# Epoch 484/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 0.9792
# Epoch 485/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 0.9792
# Epoch 486/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 0.9792
# Epoch 487/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9792
# Epoch 488/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 0.9792
# Epoch 489/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0483 - accuracy: 0.9792
# Epoch 490/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 0.9792
# Epoch 491/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9688
# Epoch 492/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9792
# Epoch 493/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9688
# Epoch 494/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.9792
# Epoch 495/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0471 - accuracy: 0.9792
# Epoch 496/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9688
# Epoch 497/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 0.9688
# Epoch 498/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.9792
# Epoch 499/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0467 - accuracy: 0.9792
# Epoch 500/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0469 - accuracy: 0.9688

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model/assets

# %%
def GetTitlesFromSoup(results):                                    #Optional, may be implemented to improve readability
    titles = []
    for word in results:
        for j in word:
            for i in j:
                for p in i:
                    is_year_of_pub = True                          #filtering out years of publication; filters everything that consists only of numbers, so a movie like 2012 will not make it to the recommendation
                    for char in p:
                        if ord(char) < 48 or ord(char) > 57:
                            is_year_of_pub = False
                            break
                    if is_year_of_pub == False:                    #Only if p is not a string of just numbers, it is put in the titles list
                        titles.append(p)
    return titles




def webscraper(x):
  from urllib.request import Request, urlopen
  from bs4 import BeautifulSoup
  import requests
  from random import randint

  #x = inp

  root = "https://www.google.com"
  link = "https://www.google.com/search?q=top+10+{}+movies&oq=top+&aqs=chrome.0.69i59l3j69i57j69i60l4.651j0j4&sourceid=chrome&ie=UTF-8".format(x)
  results = []

  req = Request(link, headers = {"User-Agent": "Mozilla/5.0"})
  webpage = urlopen(req).read()
  with requests.Session() as c:
    soup = BeautifulSoup(webpage, "html5lib")
    #print(soup)
    for item in soup.find_all('div', attrs = {"class": "RWuggc"}):
      results.append(item)

  titles = []
  for word in results:
    for j in word:
      for i in j:
        for p in i:
          is_year_of_pub = True                          #filtering out years of publication; filters everything that consists only of numbers, so a movie like 2012 will not make it to the recommendation
          for char in p:
            if ord(char) < 48 or ord(char) > 57:
              is_year_of_pub = False
              break
          if is_year_of_pub == False:                     #Only if p is not a string of just numbers, it is put in the titles list
            titles.append(p)

  #print(titles)
  end_of_titles = len(titles)
  movie_index = randint(0, end_of_titles )
  movie_index_end = movie_index + 1
  return str(*(titles[movie_index:movie_index_end]))

webscraper("action")
# Out:
# 'Terminator 2: Judgme...'

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle
translator = Translator()

#with open("intents.json") as file:
#    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20

    age_authorizer = False

    print("Are you 18 years or older?")
    age_check = input()
    if age_check == "yes":
      age_authorizer = True
    else:
      print("I'm sorry, but you have to be over 18 to use this software, since some movies are for 18+ only")

    if age_authorizer == True:

      language_detect = input("Please state the language you would like to talk in to Moviebot? \n (State the language in English please) ")
      language_detect = language_detect.lower()
      language_lib = googletrans.LANGCODES

    
    

    
    
      while True:
          print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
          inp = input()
          #language = (translator.detect(inp)).lang
          language = language_lib[language_detect]
          inp_translated = (translator.translate(inp)).text
          if inp_translated.lower() == "quit":
              break
        


          result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp_translated]),
                                              truncating='post', maxlen=max_len))
          tag = lbl_encoder.inverse_transform([np.argmax(result)])

          for i in data['intents']:
            if i['tag'] == tag:
              answer = np.random.choice(i['responses'])
              trans_answer = translator.translate(answer, dest = language).text
              print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)

          if tag == "thanks":
              answer = np.random.choice(i['responses'])
              trans_answer = translator.translate(answer, dest = language).text
              #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
              break
          if tag == "genres":
            answer = np.random.choice(i['responses'])
            trans_answer = translator.translate(answer, dest = language).text
            #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
            print(translator.translate("What about: ", dest = language).text, webscraper(inp_translated))
            genre = inp_translated
          if tag == "another":
            answer = np.random.choice(i['responses'])
            trans_answer = translator.translate(answer, dest = language).text
            #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
            print(webscraper(genre))
        
          
          



        #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# Please state the language you would like to talk in to Moviebot?
#  (State the language in English please) dutch
# User: quit

# %%
#print(googletrans.LANGUAGES)

example = "Hallo, hoe gaat het?"
transl_ex = (translator.translate(example)).text
print(transl_ex)


language = (translator.detect("Lorem Ipsum")).lang
print(language)

print((translator.translate(transl_ex, dest = language)).text)

#translations = translator.translate(['The quick brown fox', 'jumps over', 'the lazy dog'], dest='ko')
#for translation in translations:
#print(translation.origin, ' -> ', translation.text)
# The quick brown fox  ->  빠른 갈색 여우
# jumps over  ->  이상 점프
# the lazy dog  ->  게으른 개
# Out:
# Hello how are you?
# la
# Salve, quam vos?

# %%
titles = []
for word in results:
  for j in word:
    for i in j:
      for p in i:
        titles.append(p)

print(titles)

# %%
#googletrans.LANGCODES

#print("In what language would you like to talk to Moviebot?")
language_detect = input("In what language would you like to talk to Moviebot? ")
language_detect = language_detect.lower()
language_lib = googletrans.LANGCODES

print(language_lib[language_detect])
# Out:
# In what language would you like to talk to Moviebot? Dutch
# nl

# %%
#Testing
#1. Unit Testing
def LangDetectTest():
  correct_input = "Lorem Ipsum"
  incorrect_input = ""

  outcome1 = (translator.detect(correct_input)).lang
  if outcome1 == "la":
    test1 = "Success"
  else:
    test1 = "Failure"
  try:
    outcome2 = (translator.detect(incorrect_input)).lang
    test2 = "Failure"
  except:
    test2 = "Failure"
    return "Result of language detector test with correct input: {}\n\
Result of language detector test with incorrect input: {} caused by ERROR".format(test1, test2)
  else:
    return "Result of language detector test with correct input: {};\n\
Result of language detector test with incorrect input: {}".format(test1, test2)


def TranslateTest():
    correct_input = "Hello, how are you doing?"
    incorrect_input = "Reeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee\
    eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee"

    desired_outcome1 = "Hallo hoe is het?"
    
    outcome1 = translator.translate(correct_input, dest = "nl").text

    if outcome1 == desired_outcome1:
        test1 = "Success"
    else:
        test1 = "Failure"
    try:
        outcome2 = translator.translate(incorrect_input, dest = "en").text
        test2 = "Failure"
    except:
        test2 = "Failure"
        return "Result of language detector test with correct input: {}\n\
Result of language detector test with incorrect input: {} caused by ERROR".format(test1, test2)
    else:
        return "Result of language detector test with correct input: {}\n\
Result of language detector test with incorrect input: {}".format(test1, test2)


def LoadModelTest():
    try:
        model = keras.models.load_model('chat_model')
        test1 = "Success"
    except:
        test1 = "Failure"
    return "Loading the model resulted in: {}\n".format(test1)
        
    
def TitleFilterTest():
  from urllib.request import Request, urlopen
  from bs4 import BeautifulSoup
  import requests
  
  #Generating test input
  
  #correct_input = ['<div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Raid: Redemption</div></div><div><div class="BNeawe tAd8D AP7Wnd">2011</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Inception</div></div><div><div class="BNeawe tAd8D AP7Wnd">2010</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Casino Royale</div></div><div><div class="BNeawe tAd8D AP7Wnd">2006</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Matrix</div></div><div><div class="BNeawe tAd8D AP7Wnd">1999</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">John Wick</div></div><div><div class="BNeawe tAd8D AP7Wnd">2014</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Dark Knight</div></div><div><div class="BNeawe tAd8D AP7Wnd">2008</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">F9</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Die Hard</div></div><div><div class="BNeawe tAd8D AP7Wnd">1988</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Free Guy</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">No Time To Die</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Black Widow</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Tenet</div></div><div><div class="BNeawe tAd8D AP7Wnd">2020</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Extraction</div></div><div><div class="BNeawe tAd8D AP7Wnd">2020</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Mission: Impossible...</div></div><div><div class="BNeawe tAd8D AP7Wnd">2018</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Edge Of Tomorrow</div></div><div><div class="BNeawe tAd8D AP7Wnd">2014</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Atomic Blonde</div></div><div><div class="BNeawe tAd8D AP7Wnd">2017</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Old Guard</div></div><div><div class="BNeawe tAd8D AP7Wnd">2020</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Suicide Squad</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Skyfall</div></div><div><div class="BNeawe tAd8D AP7Wnd">2012</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Shang-Chi and the Le...</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Bourne Identity</div></div><div><div class="BNeawe tAd8D AP7Wnd">2002</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Avengers: Endgame</div></div><div><div class="BNeawe tAd8D AP7Wnd">2019</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Kill Bill: Vol. 1</div></div><div><div class="BNeawe tAd8D AP7Wnd">2003</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Raiders Of The Lost Ark</div></div><div><div class="BNeawe tAd8D AP7Wnd">1981</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Venom: Let There Be...</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Terminator 2: Judgme...</div></div><div><div class="BNeawe tAd8D AP7Wnd">1991</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Gladiator</div></div><div><div class="BNeawe tAd8D AP7Wnd">2000</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Mad Max 2: The Road...</div></div><div><div class="BNeawe tAd8D AP7Wnd">1981</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Aliens</div></div><div><div class="BNeawe tAd8D AP7Wnd">1986</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Point Break</div></div><div><div class="BNeawe tAd8D AP7Wnd">1991</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Speed</div></div><div><div class="BNeawe tAd8D AP7Wnd">1994</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Bourne Ultimatum</div></div><div><div class="BNeawe tAd8D AP7Wnd">2007</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Army of the Dead</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Eternals</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Raid 2</div></div><div><div class="BNeawe tAd8D AP7Wnd">2014</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Black Panther</div></div><div><div class="BNeawe tAd8D AP7Wnd">2018</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">THE FUGITIVE...</div></div><div><div class="BNeawe tAd8D AP7Wnd">1993</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Spider-Man : No Way...</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Taken</div></div><div><div class="BNeawe tAd8D AP7Wnd">2008</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Terminator</div></div><div><div class="BNeawe tAd8D AP7Wnd">1984</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Spectre</div></div><div><div class="BNeawe tAd8D AP7Wnd">2015</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">First Blood</div></div><div><div class="BNeawe tAd8D AP7Wnd">1982</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Avengers</div></div><div><div class="BNeawe tAd8D AP7Wnd">2012</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Hard Boiled</div></div><div><div class="BNeawe tAd8D AP7Wnd">1992</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Avengers: Infinity War</div></div><div><div class="BNeawe tAd8D AP7Wnd">2018</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Enter the Dragon</div></div><div><div class="BNeawe tAd8D AP7Wnd">1973</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Red Notice</div></div><div><div class="BNeawe tAd8D AP7Wnd">2021</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Lethal Weapon</div></div><div><div class="BNeawe tAd8D AP7Wnd">1989</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Ip Man</div></div><div><div class="BNeawe tAd8D AP7Wnd">2008</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Star Wars: Episode IV...</div></div><div><div class="BNeawe tAd8D AP7Wnd">1977</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">RoboCop</div></div><div><div class="BNeawe tAd8D AP7Wnd">1987</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Major Grom: Plague Do...</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Mowgli: Legend of...</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">The Witcher: N...</div></div></div>, <div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Double World</div></div></div>']
  #First tried the above input^^, was not the right format.
  root = "https://www.google.com"
  link = "https://www.google.com/search?q=top+10+{}+movies&oq=top+&aqs=chrome.0.69i59l3j69i57j69i60l4.651j0j4&sourceid=chrome&ie=UTF-8".format("action")
  results = []

  req = Request(link, headers = {"User-Agent": "Mozilla/5.0"})
  webpage = urlopen(req).read()
  with requests.Session() as c:
    soup = BeautifulSoup(webpage, "html5lib")
    #print(soup)
    for item in soup.find_all('div', attrs = {"class": "RWuggc"}):
      results.append(item)
    
  #Test 1

  desired_outcome1 = ['The Matrix', 'Die Hard', 'The Dark Knight', 'John Wick', 'Casino Royale', 'Terminator 2: Judgme...', 'Aliens', 'No Time To Die', 'Black Widow', 'Skyfall', 'Avengers: Endgame', 'Mission: Impossible...', 'Edge Of Tomorrow', 'Army of the Dead', 'Extraction', 'Free Guy', 'Shang-Chi and the Le...', 'Kill Bill: Vol. 1', 'The Suicide Squad', 'Spectre', 'Raiders Of The Lost Ark', 'The Terminator', 'Gladiator', 'The Old Guard', 'Jungle Cruise', 'Venom: Let There Be...', 'Nobody', 'Tenet', 'First Blood', 'F9', 'Predator', 'Eternals', 'Black Panther', 'V for Vendetta', 'Mad Max: Fury Road', 'Lethal Weapon', '21 Jump Street', 'Enter the Dragon', 'Inception', 'Logan', 'Red Notice', 'The Bourne Identity', 'Birds of Prey: Harl...', 'Taken', 'Mortal Kombat', 'Venom', 'Total Recall', 'Sooryavanshi', 'Thor: Ragnarok', 'Guardians of the Gala...', 'Speed', 'Monster Hunter', 'Tenet', 'The Old Guard', 'Extraction']

  test1 = "Failure"

  try:
    outcome1 = GetTitlesFromSoup(results)

  except:
    return "Result of Title Filter Test with correct input: {} caused by ERROR".format(test1)

  else:
    for title in outcome1:
      if title in desired_outcome1:
        test1 = "Success"
        break
    return "Result of Title Filter Test with correct input: {}".format(test1)

    
    
    


#2. Component/Integration testing

def WebscraperTest():
  known_genre = "action"
  unknown_genre = "bruh"

  outcome1 = webscraper(known_genre)
  if type(outcome1) == str and len(outcome1) > 0:
    test1 = "Success"
  else:
    test1 = "Failure"
  try:
    outcome2 = webscraper(unknown_genre)
    test2 = "Failure"
  except:
    test2 = "Failure"
    return "Result of webscraper test with a known genre as input: {}\n\
    Result of webscraper test with an unknown genre as input: {} caused by ERROR".format(test1, test2)
  else:
    return "Result of webscraper test with a known genre as input: {}\n\
Result of webscraper test with an unknown genre as input: {}".format(test1, test2)
# Out:
# Result of language detector test with correct input: Success
# Result of language detector test with incorrect input: Failure caused by ERROR
# Result of webscraper test with a known genre as input: Success
# Result of webscraper test with an unknown genre as input: Failure
# Result of Title Filter Test with correct input: Success

# %%
#Unit tests
print(LangDetectTest())

print(TranslateTest())

print(LoadModelTest())
print(TitleFilterTest())


#Component tests
print(WebscraperTest())
# Out:
# Result of language detector test with correct input: Success
# Result of language detector test with incorrect input: Failure caused by ERROR
# Result of language detector test with correct input: Success
# Result of language detector test with incorrect input: Failure
# Loading the model resulted in: Success
#
# Result of Title Filter Test with correct input: Success
# Result of webscraper test with a known genre as input: Success
# Result of webscraper test with an unknown genre as input: Failure

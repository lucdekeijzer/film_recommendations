# %% [markdown]
# <a href="https://colab.research.google.com/github/lucdekeijzer/film_recommendations/blob/main/chatbot_translated_bugfixed1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorama
# !pip install scikit_learn
# !pip install Flask
# !pip install beautifulsoup4
# !pip install bs4
# !pip install googletrans==4.0.0rc1
# Out:
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.4
# Requirement already satisfied: scikit_learn in /usr/local/lib/python3.7/dist-packages (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.19.5)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Collecting googletrans==4.0.0rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.6 MB/s
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (3.0.4)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2021.5.30)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2.10)
# Collecting hstspreload
#   Downloading hstspreload-2021.11.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 17.1 MB/s
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 966 kB/s
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.1 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.0 MB/s
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17415 sha256=e69a17bbfad808e00c4c45c9dbab744d9d08f6b6800c038dd3436fb106d1141a
#   Stored in directory: /root/.cache/pip/wheels/43/34/00/4fe71786ea6d12314b29037620c36d857e5d104ac2748bf82a
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
import googletrans
from googletrans import Translator
import requests
import pandas as pd

# %%
#with open('intents.json') as file:
    #data = json.load(file)

data = pd.read_json("https://raw.githubusercontent.com/lucdekeijzer/film_recommendations/main/intents.json")
 

training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 16)            16000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 16,714
# Trainable params: 16,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 4ms/step - loss: 2.3033 - accuracy: 0.0833
# Epoch 2/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3006 - accuracy: 0.1146
# Epoch 3/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2981 - accuracy: 0.1458
# Epoch 4/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2963 - accuracy: 0.1458
# Epoch 5/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2945 - accuracy: 0.1354
# Epoch 6/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2924 - accuracy: 0.1354
# Epoch 7/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2903 - accuracy: 0.1354
# Epoch 8/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2882 - accuracy: 0.1354
# Epoch 9/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2863 - accuracy: 0.1354
# Epoch 10/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2839 - accuracy: 0.1354
# Epoch 11/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2819 - accuracy: 0.1354
# Epoch 12/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2792 - accuracy: 0.1354
# Epoch 13/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2767 - accuracy: 0.3229
# Epoch 14/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2745 - accuracy: 0.3333
# Epoch 15/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2714 - accuracy: 0.3125
# Epoch 16/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2687 - accuracy: 0.3125
# Epoch 17/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2658 - accuracy: 0.2917
# Epoch 18/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2625 - accuracy: 0.2812
# Epoch 19/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2593 - accuracy: 0.2812
# Epoch 20/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2560 - accuracy: 0.2708
# Epoch 21/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2523 - accuracy: 0.2500
# Epoch 22/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2490 - accuracy: 0.2396
# Epoch 23/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2452 - accuracy: 0.2396
# Epoch 24/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2410 - accuracy: 0.2292
# Epoch 25/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2374 - accuracy: 0.2188
# Epoch 26/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2331 - accuracy: 0.2083
# Epoch 27/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2283 - accuracy: 0.2083
# Epoch 28/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2238 - accuracy: 0.2083
# Epoch 29/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2199 - accuracy: 0.2083
# Epoch 30/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2151 - accuracy: 0.2083
# Epoch 31/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2103 - accuracy: 0.2083
# Epoch 32/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2056 - accuracy: 0.2083
# Epoch 33/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2012 - accuracy: 0.2083
# Epoch 34/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1962 - accuracy: 0.2083
# Epoch 35/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1912 - accuracy: 0.2083
# Epoch 36/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1863 - accuracy: 0.2083
# Epoch 37/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1818 - accuracy: 0.2083
# Epoch 38/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1768 - accuracy: 0.2083
# Epoch 39/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1727 - accuracy: 0.2083
# Epoch 40/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1673 - accuracy: 0.2083
# Epoch 41/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1628 - accuracy: 0.2083
# Epoch 42/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1580 - accuracy: 0.2083
# Epoch 43/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1536 - accuracy: 0.2083
# Epoch 44/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1480 - accuracy: 0.2083
# Epoch 45/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1429 - accuracy: 0.2083
# Epoch 46/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1373 - accuracy: 0.2083
# Epoch 47/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1320 - accuracy: 0.2083
# Epoch 48/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1264 - accuracy: 0.2083
# Epoch 49/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1204 - accuracy: 0.2083
# Epoch 50/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1144 - accuracy: 0.2292
# Epoch 51/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1084 - accuracy: 0.2396
# Epoch 52/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1023 - accuracy: 0.2396
# Epoch 53/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0954 - accuracy: 0.2396
# Epoch 54/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0887 - accuracy: 0.2396
# Epoch 55/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0816 - accuracy: 0.2396
# Epoch 56/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0746 - accuracy: 0.2500
# Epoch 57/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0666 - accuracy: 0.2604
# Epoch 58/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0589 - accuracy: 0.2917
# Epoch 59/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0507 - accuracy: 0.2917
# Epoch 60/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0427 - accuracy: 0.2917
# Epoch 61/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0343 - accuracy: 0.2917
# Epoch 62/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0255 - accuracy: 0.2917
# Epoch 63/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0160 - accuracy: 0.2917
# Epoch 64/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0073 - accuracy: 0.2917
# Epoch 65/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9971 - accuracy: 0.2917
# Epoch 66/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9870 - accuracy: 0.2917
# Epoch 67/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9768 - accuracy: 0.2917
# Epoch 68/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9665 - accuracy: 0.2917
# Epoch 69/500
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9556 - accuracy: 0.2917
# Epoch 70/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9438 - accuracy: 0.2917
# Epoch 71/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9325 - accuracy: 0.2917
# Epoch 72/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9192 - accuracy: 0.2917
# Epoch 73/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9073 - accuracy: 0.2917
# Epoch 74/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8949 - accuracy: 0.2917
# Epoch 75/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8825 - accuracy: 0.2917
# Epoch 76/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8690 - accuracy: 0.3021
# Epoch 77/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8563 - accuracy: 0.3021
# Epoch 78/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8435 - accuracy: 0.3125
# Epoch 79/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8297 - accuracy: 0.3125
# Epoch 80/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8165 - accuracy: 0.3125
# Epoch 81/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8029 - accuracy: 0.3438
# Epoch 82/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7895 - accuracy: 0.3854
# Epoch 83/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7761 - accuracy: 0.3750
# Epoch 84/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7630 - accuracy: 0.4167
# Epoch 85/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7494 - accuracy: 0.4167
# Epoch 86/500
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7361 - accuracy: 0.3958
# Epoch 87/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7224 - accuracy: 0.3958
# Epoch 88/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7097 - accuracy: 0.3750
# Epoch 89/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6968 - accuracy: 0.3750
# Epoch 90/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6829 - accuracy: 0.3750
# Epoch 91/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6704 - accuracy: 0.3750
# Epoch 92/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6577 - accuracy: 0.3750
# Epoch 93/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6453 - accuracy: 0.3750
# Epoch 94/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6327 - accuracy: 0.3750
# Epoch 95/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.6201 - accuracy: 0.3750
# Epoch 96/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6076 - accuracy: 0.3750
# Epoch 97/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5950 - accuracy: 0.3750
# Epoch 98/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5835 - accuracy: 0.3750
# Epoch 99/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5707 - accuracy: 0.3750
# Epoch 100/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5581 - accuracy: 0.3750
# Epoch 101/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5453 - accuracy: 0.3750
# Epoch 102/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5339 - accuracy: 0.3854
# Epoch 103/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5214 - accuracy: 0.3854
# Epoch 104/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5092 - accuracy: 0.3958
# Epoch 105/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4974 - accuracy: 0.4167
# Epoch 106/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4847 - accuracy: 0.4375
# Epoch 107/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4729 - accuracy: 0.4375
# Epoch 108/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4608 - accuracy: 0.4583
# Epoch 109/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4482 - accuracy: 0.4583
# Epoch 110/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4362 - accuracy: 0.4792
# Epoch 111/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4242 - accuracy: 0.5000
# Epoch 112/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4119 - accuracy: 0.5208
# Epoch 113/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4004 - accuracy: 0.5312
# Epoch 114/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3885 - accuracy: 0.5312
# Epoch 115/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3779 - accuracy: 0.5312
# Epoch 116/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3652 - accuracy: 0.5312
# Epoch 117/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3536 - accuracy: 0.5417
# Epoch 118/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3409 - accuracy: 0.5625
# Epoch 119/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3299 - accuracy: 0.5625
# Epoch 120/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3170 - accuracy: 0.5729
# Epoch 121/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3056 - accuracy: 0.5729
# Epoch 122/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2951 - accuracy: 0.5625
# Epoch 123/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2826 - accuracy: 0.5729
# Epoch 124/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2701 - accuracy: 0.5938
# Epoch 125/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2582 - accuracy: 0.5938
# Epoch 126/500
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2464 - accuracy: 0.5938
# Epoch 127/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2347 - accuracy: 0.5938
# Epoch 128/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2232 - accuracy: 0.6042
# Epoch 129/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2114 - accuracy: 0.6042
# Epoch 130/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1991 - accuracy: 0.6042
# Epoch 131/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1882 - accuracy: 0.6042
# Epoch 132/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1770 - accuracy: 0.6042
# Epoch 133/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1653 - accuracy: 0.6042
# Epoch 134/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1547 - accuracy: 0.6042
# Epoch 135/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1444 - accuracy: 0.6042
# Epoch 136/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1309 - accuracy: 0.6042
# Epoch 137/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1206 - accuracy: 0.6146
# Epoch 138/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1097 - accuracy: 0.6146
# Epoch 139/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.6146
# Epoch 140/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0881 - accuracy: 0.6146
# Epoch 141/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0776 - accuracy: 0.6146
# Epoch 142/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0672 - accuracy: 0.6146
# Epoch 143/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0582 - accuracy: 0.6146
# Epoch 144/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0468 - accuracy: 0.6146
# Epoch 145/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0369 - accuracy: 0.6146
# Epoch 146/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0263 - accuracy: 0.6146
# Epoch 147/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0164 - accuracy: 0.6250
# Epoch 148/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0074 - accuracy: 0.6250
# Epoch 149/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9965 - accuracy: 0.6250
# Epoch 150/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9864 - accuracy: 0.6250
# Epoch 151/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9775 - accuracy: 0.6250
# Epoch 152/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9673 - accuracy: 0.6250
# Epoch 153/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9577 - accuracy: 0.6250
# Epoch 154/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.9482 - accuracy: 0.6458
# Epoch 155/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9386 - accuracy: 0.6667
# Epoch 156/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9298 - accuracy: 0.6667
# Epoch 157/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9199 - accuracy: 0.6667
# Epoch 158/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9116 - accuracy: 0.6667
# Epoch 159/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9016 - accuracy: 0.6667
# Epoch 160/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8924 - accuracy: 0.6875
# Epoch 161/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8842 - accuracy: 0.6875
# Epoch 162/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8742 - accuracy: 0.6875
# Epoch 163/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8655 - accuracy: 0.6771
# Epoch 164/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8569 - accuracy: 0.6771
# Epoch 165/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8486 - accuracy: 0.6875
# Epoch 166/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8386 - accuracy: 0.6875
# Epoch 167/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8304 - accuracy: 0.6875
# Epoch 168/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8217 - accuracy: 0.6875
# Epoch 169/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8138 - accuracy: 0.6979
# Epoch 170/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8043 - accuracy: 0.6979
# Epoch 171/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7965 - accuracy: 0.6979
# Epoch 172/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7887 - accuracy: 0.6979
# Epoch 173/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7790 - accuracy: 0.7292
# Epoch 174/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7714 - accuracy: 0.7292
# Epoch 175/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7640 - accuracy: 0.7396
# Epoch 176/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7548 - accuracy: 0.7604
# Epoch 177/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7474 - accuracy: 0.7812
# Epoch 178/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7397 - accuracy: 0.7917
# Epoch 179/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7320 - accuracy: 0.8021
# Epoch 180/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7238 - accuracy: 0.8021
# Epoch 181/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7159 - accuracy: 0.8021
# Epoch 182/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7110 - accuracy: 0.8021
# Epoch 183/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7010 - accuracy: 0.8021
# Epoch 184/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.8021
# Epoch 185/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6856 - accuracy: 0.8021
# Epoch 186/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6777 - accuracy: 0.8229
# Epoch 187/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6712 - accuracy: 0.8229
# Epoch 188/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6634 - accuracy: 0.8229
# Epoch 189/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6561 - accuracy: 0.8229
# Epoch 190/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6498 - accuracy: 0.8229
# Epoch 191/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6429 - accuracy: 0.8229
# Epoch 192/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6359 - accuracy: 0.8229
# Epoch 193/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6279 - accuracy: 0.8229
# Epoch 194/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6213 - accuracy: 0.8229
# Epoch 195/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6144 - accuracy: 0.8333
# Epoch 196/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6068 - accuracy: 0.8333
# Epoch 197/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5997 - accuracy: 0.8333
# Epoch 198/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5933 - accuracy: 0.8333
# Epoch 199/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5861 - accuracy: 0.8333
# Epoch 200/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5799 - accuracy: 0.8333
# Epoch 201/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5744 - accuracy: 0.8438
# Epoch 202/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5667 - accuracy: 0.8438
# Epoch 203/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5620 - accuracy: 0.8333
# Epoch 204/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5555 - accuracy: 0.8438
# Epoch 205/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5473 - accuracy: 0.8438
# Epoch 206/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5410 - accuracy: 0.8438
# Epoch 207/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5354 - accuracy: 0.8438
# Epoch 208/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5286 - accuracy: 0.8542
# Epoch 209/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5230 - accuracy: 0.8542
# Epoch 210/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5170 - accuracy: 0.8542
# Epoch 211/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.8646
# Epoch 212/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5047 - accuracy: 0.8542
# Epoch 213/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4982 - accuracy: 0.8646
# Epoch 214/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4931 - accuracy: 0.8542
# Epoch 215/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4874 - accuracy: 0.8646
# Epoch 216/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.8646
# Epoch 217/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4753 - accuracy: 0.8646
# Epoch 218/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4706 - accuracy: 0.8646
# Epoch 219/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4645 - accuracy: 0.8750
# Epoch 220/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4585 - accuracy: 0.8646
# Epoch 221/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4533 - accuracy: 0.8750
# Epoch 222/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4476 - accuracy: 0.8854
# Epoch 223/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4423 - accuracy: 0.8854
# Epoch 224/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4384 - accuracy: 0.8854
# Epoch 225/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4341 - accuracy: 0.8958
# Epoch 226/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4289 - accuracy: 0.8750
# Epoch 227/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4228 - accuracy: 0.8958
# Epoch 228/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4172 - accuracy: 0.8958
# Epoch 229/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4114 - accuracy: 0.8854
# Epoch 230/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4080 - accuracy: 0.9271
# Epoch 231/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4027 - accuracy: 0.9479
# Epoch 232/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3965 - accuracy: 0.9479
# Epoch 233/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3921 - accuracy: 0.9375
# Epoch 234/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3873 - accuracy: 0.9479
# Epoch 235/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3826 - accuracy: 0.9479
# Epoch 236/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3773 - accuracy: 0.9479
# Epoch 237/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3730 - accuracy: 0.9479
# Epoch 238/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3684 - accuracy: 0.9479
# Epoch 239/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3635 - accuracy: 0.9479
# Epoch 240/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3592 - accuracy: 0.9479
# Epoch 241/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.9479
# Epoch 242/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3502 - accuracy: 0.9375
# Epoch 243/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3464 - accuracy: 0.9583
# Epoch 244/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3415 - accuracy: 0.9583
# Epoch 245/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3376 - accuracy: 0.9583
# Epoch 246/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3327 - accuracy: 0.9583
# Epoch 247/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3297 - accuracy: 0.9583
# Epoch 248/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3246 - accuracy: 0.9583
# Epoch 249/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3209 - accuracy: 0.9583
# Epoch 250/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3163 - accuracy: 0.9583
# Epoch 251/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3132 - accuracy: 0.9583
# Epoch 252/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3080 - accuracy: 0.9583
# Epoch 253/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.9583
# Epoch 254/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2993 - accuracy: 0.9583
# Epoch 255/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2962 - accuracy: 0.9583
# Epoch 256/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2924 - accuracy: 0.9688
# Epoch 257/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.9792
# Epoch 258/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2837 - accuracy: 0.9792
# Epoch 259/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.9792
# Epoch 260/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.9688
# Epoch 261/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2712 - accuracy: 0.9792
# Epoch 262/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2662 - accuracy: 0.9792
# Epoch 263/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.9792
# Epoch 264/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.9792
# Epoch 265/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2553 - accuracy: 0.9792
# Epoch 266/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2514 - accuracy: 0.9792
# Epoch 267/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2474 - accuracy: 0.9792
# Epoch 268/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2443 - accuracy: 0.9688
# Epoch 269/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2403 - accuracy: 0.9792
# Epoch 270/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2366 - accuracy: 0.9792
# Epoch 271/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2334 - accuracy: 0.9792
# Epoch 272/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2305 - accuracy: 0.9792
# Epoch 273/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 0.9792
# Epoch 274/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.9688
# Epoch 275/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2208 - accuracy: 0.9792
# Epoch 276/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2176 - accuracy: 0.9792
# Epoch 277/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.9792
# Epoch 278/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2120 - accuracy: 0.9792
# Epoch 279/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2087 - accuracy: 0.9792
# Epoch 280/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2067 - accuracy: 0.9792
# Epoch 281/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2034 - accuracy: 0.9688
# Epoch 282/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2012 - accuracy: 0.9688
# Epoch 283/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1978 - accuracy: 0.9792
# Epoch 284/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1952 - accuracy: 0.9792
# Epoch 285/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1938 - accuracy: 0.9688
# Epoch 286/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1906 - accuracy: 0.9792
# Epoch 287/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1878 - accuracy: 0.9792
# Epoch 288/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.9792
# Epoch 289/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9792
# Epoch 290/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9792
# Epoch 291/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9792
# Epoch 292/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1764 - accuracy: 0.9792
# Epoch 293/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1740 - accuracy: 0.9792
# Epoch 294/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1726 - accuracy: 0.9688
# Epoch 295/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1701 - accuracy: 0.9688
# Epoch 296/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1677 - accuracy: 0.9792
# Epoch 297/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9688
# Epoch 298/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1636 - accuracy: 0.9688
# Epoch 299/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1618 - accuracy: 0.9688
# Epoch 300/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1605 - accuracy: 0.9688
# Epoch 301/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9792
# Epoch 302/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9792
# Epoch 303/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1546 - accuracy: 0.9792
# Epoch 304/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1529 - accuracy: 0.9688
# Epoch 305/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1503 - accuracy: 0.9792
# Epoch 306/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1487 - accuracy: 0.9792
# Epoch 307/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1471 - accuracy: 0.9792
# Epoch 308/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1459 - accuracy: 0.9688
# Epoch 309/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9792
# Epoch 310/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1432 - accuracy: 0.9792
# Epoch 311/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1412 - accuracy: 0.9792
# Epoch 312/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1392 - accuracy: 0.9792
# Epoch 313/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1375 - accuracy: 0.9688
# Epoch 314/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9792
# Epoch 315/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1351 - accuracy: 0.9792
# Epoch 316/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1328 - accuracy: 0.9792
# Epoch 317/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1314 - accuracy: 0.9792
# Epoch 318/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1304 - accuracy: 0.9792
# Epoch 319/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9792
# Epoch 320/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1278 - accuracy: 0.9792
# Epoch 321/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9792
# Epoch 322/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1254 - accuracy: 0.9688
# Epoch 323/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1239 - accuracy: 0.9792
# Epoch 324/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.9792
# Epoch 325/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.9792
# Epoch 326/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1201 - accuracy: 0.9792
# Epoch 327/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1196 - accuracy: 0.9688
# Epoch 328/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1174 - accuracy: 0.9792
# Epoch 329/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1165 - accuracy: 0.9688
# Epoch 330/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1156 - accuracy: 0.9792
# Epoch 331/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1143 - accuracy: 0.9792
# Epoch 332/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1128 - accuracy: 0.9792
# Epoch 333/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1119 - accuracy: 0.9792
# Epoch 334/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1110 - accuracy: 0.9792
# Epoch 335/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1099 - accuracy: 0.9792
# Epoch 336/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1089 - accuracy: 0.9792
# Epoch 337/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1080 - accuracy: 0.9792
# Epoch 338/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1073 - accuracy: 0.9792
# Epoch 339/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1057 - accuracy: 0.9792
# Epoch 340/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1052 - accuracy: 0.9688
# Epoch 341/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1040 - accuracy: 0.9792
# Epoch 342/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1031 - accuracy: 0.9792
# Epoch 343/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1021 - accuracy: 0.9792
# Epoch 344/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1014 - accuracy: 0.9688
# Epoch 345/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9792
# Epoch 346/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0994 - accuracy: 0.9792
# Epoch 347/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0990 - accuracy: 0.9688
# Epoch 348/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.9792
# Epoch 349/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0971 - accuracy: 0.9792
# Epoch 350/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0977 - accuracy: 0.9688
# Epoch 351/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9792
# Epoch 352/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9792
# Epoch 353/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9688
# Epoch 354/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0937 - accuracy: 0.9792
# Epoch 355/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0924 - accuracy: 0.9792
# Epoch 356/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0915 - accuracy: 0.9792
# Epoch 357/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0905 - accuracy: 0.9792
# Epoch 358/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9792
# Epoch 359/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0897 - accuracy: 0.9688
# Epoch 360/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0889 - accuracy: 0.9688
# Epoch 361/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0876 - accuracy: 0.9792
# Epoch 362/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0879 - accuracy: 0.9792
# Epoch 363/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0863 - accuracy: 0.9792
# Epoch 364/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0859 - accuracy: 0.9792
# Epoch 365/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0854 - accuracy: 0.9792
# Epoch 366/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9792
# Epoch 367/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9688
# Epoch 368/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9792
# Epoch 369/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0828 - accuracy: 0.9792
# Epoch 370/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.9688
# Epoch 371/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0820 - accuracy: 0.9792
# Epoch 372/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9688
# Epoch 373/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0806 - accuracy: 0.9792
# Epoch 374/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9792
# Epoch 375/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0799 - accuracy: 0.9792
# Epoch 376/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0790 - accuracy: 0.9792
# Epoch 377/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9792
# Epoch 378/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9792
# Epoch 379/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 0.9688
# Epoch 380/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9688
# Epoch 381/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 0.9688
# Epoch 382/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9792
# Epoch 383/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0755 - accuracy: 0.9688
# Epoch 384/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0753 - accuracy: 0.9688
# Epoch 385/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9792
# Epoch 386/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9688
# Epoch 387/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0735 - accuracy: 0.9792
# Epoch 388/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.9792
# Epoch 389/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0723 - accuracy: 0.9792
# Epoch 390/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0730 - accuracy: 0.9688
# Epoch 391/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0717 - accuracy: 0.9792
# Epoch 392/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0709 - accuracy: 0.9792
# Epoch 393/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.9688
# Epoch 394/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0704 - accuracy: 0.9792
# Epoch 395/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0705 - accuracy: 0.9792
# Epoch 396/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0691 - accuracy: 0.9792
# Epoch 397/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0693 - accuracy: 0.9792
# Epoch 398/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0693 - accuracy: 0.9792
# Epoch 399/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0687 - accuracy: 0.9792
# Epoch 400/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0681 - accuracy: 0.9792
# Epoch 401/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0680 - accuracy: 0.9792
# Epoch 402/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9792
# Epoch 403/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0672 - accuracy: 0.9792
# Epoch 404/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0668 - accuracy: 0.9688
# Epoch 405/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0662 - accuracy: 0.9688
# Epoch 406/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0659 - accuracy: 0.9792
# Epoch 407/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0664 - accuracy: 0.9792
# Epoch 408/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0650 - accuracy: 0.9792
# Epoch 409/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0647 - accuracy: 0.9792
# Epoch 410/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9792
# Epoch 411/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0640 - accuracy: 0.9792
# Epoch 412/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0642 - accuracy: 0.9792
# Epoch 413/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9688
# Epoch 414/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0635 - accuracy: 0.9688
# Epoch 415/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0630 - accuracy: 0.9792
# Epoch 416/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 0.9792
# Epoch 417/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9792
# Epoch 418/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0623 - accuracy: 0.9792
# Epoch 419/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0617 - accuracy: 0.9792
# Epoch 420/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9792
# Epoch 421/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0611 - accuracy: 0.9792
# Epoch 422/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 0.9792
# Epoch 423/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0601 - accuracy: 0.9792
# Epoch 424/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 0.9792
# Epoch 425/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0604 - accuracy: 0.9688
# Epoch 426/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0595 - accuracy: 0.9792
# Epoch 427/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 0.9792
# Epoch 428/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 0.9688
# Epoch 429/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0589 - accuracy: 0.9792
# Epoch 430/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0585 - accuracy: 0.9688
# Epoch 431/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9792
# Epoch 432/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0583 - accuracy: 0.9688
# Epoch 433/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0586 - accuracy: 0.9688
# Epoch 434/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9792
# Epoch 435/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0569 - accuracy: 0.9792
# Epoch 436/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9688
# Epoch 437/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9792
# Epoch 438/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0566 - accuracy: 0.9792
# Epoch 439/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0562 - accuracy: 0.9792
# Epoch 440/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0565 - accuracy: 0.9688
# Epoch 441/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0559 - accuracy: 0.9792
# Epoch 442/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 0.9688
# Epoch 443/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9792
# Epoch 444/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9688
# Epoch 445/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0551 - accuracy: 0.9688
# Epoch 446/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0552 - accuracy: 0.9792
# Epoch 447/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0546 - accuracy: 0.9792
# Epoch 448/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9792
# Epoch 449/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 0.9792
# Epoch 450/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9792
# Epoch 451/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0540 - accuracy: 0.9792
# Epoch 452/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9792
# Epoch 453/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0534 - accuracy: 0.9792
# Epoch 454/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0535 - accuracy: 0.9688
# Epoch 455/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9792
# Epoch 456/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0532 - accuracy: 0.9792
# Epoch 457/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0528 - accuracy: 0.9792
# Epoch 458/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0530 - accuracy: 0.9792
# Epoch 459/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0523 - accuracy: 0.9792
# Epoch 460/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9792
# Epoch 461/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 0.9688
# Epoch 462/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0526 - accuracy: 0.9792
# Epoch 463/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0515 - accuracy: 0.9792
# Epoch 464/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0516 - accuracy: 0.9688
# Epoch 465/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0515 - accuracy: 0.9792
# Epoch 466/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 0.9688
# Epoch 467/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0507 - accuracy: 0.9792
# Epoch 468/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0503 - accuracy: 0.9792
# Epoch 469/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0504 - accuracy: 0.9792
# Epoch 470/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 0.9792
# Epoch 471/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0501 - accuracy: 0.9688
# Epoch 472/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.9688
# Epoch 473/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0502 - accuracy: 0.9688
# Epoch 474/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.9792
# Epoch 475/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0493 - accuracy: 0.9792
# Epoch 476/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0496 - accuracy: 0.9688
# Epoch 477/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0497 - accuracy: 0.9792
# Epoch 478/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 0.9792
# Epoch 479/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0492 - accuracy: 0.9792
# Epoch 480/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 0.9792
# Epoch 481/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 0.9792
# Epoch 482/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0485 - accuracy: 0.9792
# Epoch 483/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 0.9792
# Epoch 484/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0485 - accuracy: 0.9792
# Epoch 485/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0478 - accuracy: 0.9792
# Epoch 486/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0483 - accuracy: 0.9792
# Epoch 487/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9792
# Epoch 488/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0482 - accuracy: 0.9688
# Epoch 489/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0475 - accuracy: 0.9792
# Epoch 490/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9688
# Epoch 491/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0481 - accuracy: 0.9688
# Epoch 492/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0469 - accuracy: 0.9792
# Epoch 493/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0467 - accuracy: 0.9792
# Epoch 494/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0466 - accuracy: 0.9792
# Epoch 495/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0469 - accuracy: 0.9688
# Epoch 496/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0468 - accuracy: 0.9792
# Epoch 497/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0465 - accuracy: 0.9688
# Epoch 498/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0464 - accuracy: 0.9792
# Epoch 499/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0471 - accuracy: 0.9688
# Epoch 500/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0473 - accuracy: 0.9688

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model/assets

# %%
def webscraper(x):
  from urllib.request import Request, urlopen
  from bs4 import BeautifulSoup
  import requests
  from random import randint

  #x = inp

  root = "https://www.google.com"
  link = "https://www.google.com/search?q=top+10+{}+movies&oq=top+&aqs=chrome.0.69i59l3j69i57j69i60l4.651j0j4&sourceid=chrome&ie=UTF-8".format(x)
  results = []

  req = Request(link, headers = {"User-Agent": "Mozilla/5.0"})
  webpage = urlopen(req).read()
  with requests.Session() as c:
    soup = BeautifulSoup(webpage, "html5lib")
    #print(soup)
    for item in soup.find_all('div', attrs = {"class": "RWuggc"}):
      results.append(item)

  titles = []
  
  for word in results:
    for j in word:
      for i in j:
        for p in i:
          is_year_of_pub = True                          #filtering out years of publication; filters everything that consists only of numbers, so a movie like 2012 will not make it to the recommendation
          for char in p:
            if ord(char) < 48 or ord(char) > 57:
              is_year_of_pub = False
              break
          if is_year_of_pub == False:                     #Only if p is not a string of numbers, it is put in the titles list
            titles.append(p)

  #print(titles)
  end_of_titles = len(titles)
  movie_index = randint(0, end_of_titles )
  movie_index_end = movie_index + 1
  return str(*(titles[movie_index:movie_index_end]))

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle
translator = Translator()

#with open("intents.json") as file:
#    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        language = (translator.detect(inp)).lang
        inp_translated = (translator.translate(inp)).text
        if inp_translated.lower() == "quit":
            break
        


        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp_translated]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])

        for i in data['intents']:
          if i['tag'] == tag:
            answer = np.random.choice(i['responses'])
            trans_answer = translator.translate(answer, dest = language).text
            print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)

        if tag == "thanks":
            answer = np.random.choice(i['responses'])
            trans_answer = translator.translate(answer, dest = language).text
            #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
            break
        if tag == "genres":
          answer = np.random.choice(i['responses'])
          trans_answer = translator.translate(answer, dest = language).text
          #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
          print("What about: ", webscraper(inp_translated))
          genre = inp_translated
        if tag == "another":
          answer = np.random.choice(i['responses'])
          trans_answer = translator.translate(answer, dest = language).text
          #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
          print(webscraper(genre))
        
          
          



        #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# User: hi there
# ChatBot: Hi
# User: I would like to watch a movie
# ChatBot: What's the first genre that comes to your mind?
# User: action
# ChatBot: I'll check what movie you'd maybe like to watch
# What about  Enter the Dragon
# User:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-6914e470805b> in <module>()
#      76
#      77 print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
# ---> 78 chat()
#
# <ipython-input-30-6914e470805b> in chat()
#      33     while True:
#      34         print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
# ---> 35         inp = input()
#      36         language = (translator.detect(inp)).lang
#      37         inp_translated = (translator.translate(inp)).text
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
#print(googletrans.LANGUAGES)

example = "Hallo, hoe gaat het?"
transl_ex = (translator.translate(example)).text
print(transl_ex)


language = (translator.detect("Lorem Ipsum")).lang
print(language)

print((translator.translate(transl_ex, dest = language)).text)

#translations = translator.translate(['The quick brown fox', 'jumps over', 'the lazy dog'], dest='ko')
#for translation in translations:
#print(translation.origin, ' -> ', translation.text)
# The quick brown fox  ->  빠른 갈색 여우
# jumps over  ->  이상 점프
# the lazy dog  ->  게으른 개

# %%
titles = []
for word in results:
  for j in word:
    for i in j:
      for p in i:
        titles.append(p)

print(titles)

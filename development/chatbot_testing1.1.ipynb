# %% [markdown]
# <a href="https://colab.research.google.com/github/lucdekeijzer/film_recommendations/blob/main/chatbot_testing1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorama
# !pip install scikit_learn
# !pip install Flask
# !pip install beautifulsoup4
# !pip install bs4
# !pip install googletrans==4.0.0rc1
# Out:
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.4
# Requirement already satisfied: scikit_learn in /usr/local/lib/python3.7/dist-packages (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit_learn) (1.1.0)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Collecting googletrans==4.0.0rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 1.7 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2021.10.8)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2.10)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (3.0.4)
# Collecting hstspreload
#   Downloading hstspreload-2021.11.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 9.0 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.5 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.9 MB/s
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17415 sha256=151e2ec00fd3d32880d895cf48cc64e6a17a41155da434e31bf1ea8d79a8a24e
#   Stored in directory: /root/.cache/pip/wheels/43/34/00/4fe71786ea6d12314b29037620c36d857e5d104ac2748bf82a
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
import googletrans
from googletrans import Translator
import requests
import pandas as pd

# %%
#with open('intents.json') as file:
    #data = json.load(file)

data = pd.read_json("https://raw.githubusercontent.com/lucdekeijzer/film_recommendations/main/intents.json")
 

training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 16,714
# Trainable params: 16,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 6ms/step - loss: 2.3028 - accuracy: 0.0729
# Epoch 2/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3002 - accuracy: 0.1354
# Epoch 3/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2981 - accuracy: 0.1354
# Epoch 4/500
# 3/3 [==============================] - 0s 9ms/step - loss: 2.2957 - accuracy: 0.1354
# Epoch 5/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2938 - accuracy: 0.1354
# Epoch 6/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2917 - accuracy: 0.1354
# Epoch 7/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2891 - accuracy: 0.1354
# Epoch 8/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2870 - accuracy: 0.1354
# Epoch 9/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2843 - accuracy: 0.1354
# Epoch 10/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2819 - accuracy: 0.1354
# Epoch 11/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2785 - accuracy: 0.1354
# Epoch 12/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2762 - accuracy: 0.1354
# Epoch 13/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2729 - accuracy: 0.1354
# Epoch 14/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2698 - accuracy: 0.1354
# Epoch 15/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2672 - accuracy: 0.1354
# Epoch 16/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2634 - accuracy: 0.1354
# Epoch 17/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2597 - accuracy: 0.1354
# Epoch 18/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2566 - accuracy: 0.1354
# Epoch 19/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2523 - accuracy: 0.1354
# Epoch 20/500
# 3/3 [==============================] - 0s 8ms/step - loss: 2.2489 - accuracy: 0.1354
# Epoch 21/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2447 - accuracy: 0.1354
# Epoch 22/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2405 - accuracy: 0.1354
# Epoch 23/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2364 - accuracy: 0.1354
# Epoch 24/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2320 - accuracy: 0.1354
# Epoch 25/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2273 - accuracy: 0.1354
# Epoch 26/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2224 - accuracy: 0.1354
# Epoch 27/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2183 - accuracy: 0.1354
# Epoch 28/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2128 - accuracy: 0.1354
# Epoch 29/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2081 - accuracy: 0.1354
# Epoch 30/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2030 - accuracy: 0.1354
# Epoch 31/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1984 - accuracy: 0.1354
# Epoch 32/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1934 - accuracy: 0.1354
# Epoch 33/500
# 3/3 [==============================] - 0s 8ms/step - loss: 2.1883 - accuracy: 0.1354
# Epoch 34/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1827 - accuracy: 0.1354
# Epoch 35/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1773 - accuracy: 0.1354
# Epoch 36/500
# 3/3 [==============================] - 0s 9ms/step - loss: 2.1719 - accuracy: 0.2500
# Epoch 37/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1660 - accuracy: 0.3333
# Epoch 38/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1605 - accuracy: 0.3438
# Epoch 39/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1545 - accuracy: 0.3229
# Epoch 40/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1496 - accuracy: 0.3021
# Epoch 41/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1424 - accuracy: 0.2917
# Epoch 42/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1362 - accuracy: 0.2917
# Epoch 43/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1296 - accuracy: 0.2917
# Epoch 44/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1229 - accuracy: 0.2917
# Epoch 45/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1165 - accuracy: 0.2812
# Epoch 46/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1093 - accuracy: 0.2708
# Epoch 47/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1022 - accuracy: 0.2708
# Epoch 48/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0945 - accuracy: 0.2708
# Epoch 49/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0869 - accuracy: 0.2708
# Epoch 50/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0794 - accuracy: 0.2708
# Epoch 51/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0714 - accuracy: 0.2708
# Epoch 52/500
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0629 - accuracy: 0.2708
# Epoch 53/500
# 3/3 [==============================] - 0s 12ms/step - loss: 2.0547 - accuracy: 0.2708
# Epoch 54/500
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0459 - accuracy: 0.2708
# Epoch 55/500
# 3/3 [==============================] - 0s 8ms/step - loss: 2.0371 - accuracy: 0.2812
# Epoch 56/500
# 3/3 [==============================] - 0s 10ms/step - loss: 2.0278 - accuracy: 0.2708
# Epoch 57/500
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0188 - accuracy: 0.2812
# Epoch 58/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0095 - accuracy: 0.2917
# Epoch 59/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.9992 - accuracy: 0.2917
# Epoch 60/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9893 - accuracy: 0.2917
# Epoch 61/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9797 - accuracy: 0.2917
# Epoch 62/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9691 - accuracy: 0.2917
# Epoch 63/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9587 - accuracy: 0.2917
# Epoch 64/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9495 - accuracy: 0.2917
# Epoch 65/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9377 - accuracy: 0.2917
# Epoch 66/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.9272 - accuracy: 0.2917
# Epoch 67/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.9167 - accuracy: 0.2917
# Epoch 68/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9059 - accuracy: 0.2917
# Epoch 69/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8949 - accuracy: 0.2917
# Epoch 70/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8844 - accuracy: 0.2917
# Epoch 71/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8734 - accuracy: 0.2917
# Epoch 72/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8623 - accuracy: 0.2917
# Epoch 73/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8525 - accuracy: 0.2917
# Epoch 74/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8416 - accuracy: 0.3021
# Epoch 75/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8306 - accuracy: 0.3021
# Epoch 76/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.8201 - accuracy: 0.3021
# Epoch 77/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.8094 - accuracy: 0.3021
# Epoch 78/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7988 - accuracy: 0.3229
# Epoch 79/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7887 - accuracy: 0.3333
# Epoch 80/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7785 - accuracy: 0.3333
# Epoch 81/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7684 - accuracy: 0.3542
# Epoch 82/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7577 - accuracy: 0.3646
# Epoch 83/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7481 - accuracy: 0.3750
# Epoch 84/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7376 - accuracy: 0.3750
# Epoch 85/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7276 - accuracy: 0.3750
# Epoch 86/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7183 - accuracy: 0.3750
# Epoch 87/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7081 - accuracy: 0.3854
# Epoch 88/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6983 - accuracy: 0.3958
# Epoch 89/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6888 - accuracy: 0.3958
# Epoch 90/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6794 - accuracy: 0.4167
# Epoch 91/500
# 3/3 [==============================] - 0s 10ms/step - loss: 1.6695 - accuracy: 0.4167
# Epoch 92/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6608 - accuracy: 0.4167
# Epoch 93/500
# 3/3 [==============================] - 0s 12ms/step - loss: 1.6509 - accuracy: 0.4271
# Epoch 94/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6412 - accuracy: 0.4375
# Epoch 95/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6319 - accuracy: 0.4375
# Epoch 96/500
# 3/3 [==============================] - 0s 10ms/step - loss: 1.6223 - accuracy: 0.4479
# Epoch 97/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6131 - accuracy: 0.4479
# Epoch 98/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6044 - accuracy: 0.4479
# Epoch 99/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5954 - accuracy: 0.4479
# Epoch 100/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5859 - accuracy: 0.4479
# Epoch 101/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5777 - accuracy: 0.4479
# Epoch 102/500
# 3/3 [==============================] - 0s 10ms/step - loss: 1.5683 - accuracy: 0.4583
# Epoch 103/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.5601 - accuracy: 0.4688
# Epoch 104/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5506 - accuracy: 0.4792
# Epoch 105/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5413 - accuracy: 0.4792
# Epoch 106/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5332 - accuracy: 0.4896
# Epoch 107/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5236 - accuracy: 0.5104
# Epoch 108/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5148 - accuracy: 0.5208
# Epoch 109/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5057 - accuracy: 0.5312
# Epoch 110/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4973 - accuracy: 0.5312
# Epoch 111/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4886 - accuracy: 0.5417
# Epoch 112/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4791 - accuracy: 0.5417
# Epoch 113/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4704 - accuracy: 0.5417
# Epoch 114/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4619 - accuracy: 0.5417
# Epoch 115/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.4536 - accuracy: 0.5417
# Epoch 116/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4446 - accuracy: 0.5417
# Epoch 117/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4353 - accuracy: 0.5417
# Epoch 118/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4267 - accuracy: 0.5417
# Epoch 119/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4175 - accuracy: 0.5417
# Epoch 120/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4080 - accuracy: 0.5521
# Epoch 121/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3990 - accuracy: 0.5521
# Epoch 122/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3907 - accuracy: 0.5521
# Epoch 123/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3808 - accuracy: 0.5521
# Epoch 124/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3716 - accuracy: 0.5521
# Epoch 125/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3623 - accuracy: 0.5521
# Epoch 126/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3537 - accuracy: 0.5521
# Epoch 127/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3443 - accuracy: 0.5729
# Epoch 128/500
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3350 - accuracy: 0.5729
# Epoch 129/500
# 3/3 [==============================] - 0s 9ms/step - loss: 1.3254 - accuracy: 0.5729
# Epoch 130/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3158 - accuracy: 0.5729
# Epoch 131/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3064 - accuracy: 0.5833
# Epoch 132/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2958 - accuracy: 0.5938
# Epoch 133/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2863 - accuracy: 0.5938
# Epoch 134/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2772 - accuracy: 0.5938
# Epoch 135/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2659 - accuracy: 0.5938
# Epoch 136/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2564 - accuracy: 0.5938
# Epoch 137/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2467 - accuracy: 0.5938
# Epoch 138/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2391 - accuracy: 0.5938
# Epoch 139/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2276 - accuracy: 0.5938
# Epoch 140/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2190 - accuracy: 0.5938
# Epoch 141/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2093 - accuracy: 0.5938
# Epoch 142/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2000 - accuracy: 0.5938
# Epoch 143/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1906 - accuracy: 0.5938
# Epoch 144/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1811 - accuracy: 0.5938
# Epoch 145/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1726 - accuracy: 0.5833
# Epoch 146/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1628 - accuracy: 0.5938
# Epoch 147/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1540 - accuracy: 0.6042
# Epoch 148/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1449 - accuracy: 0.5938
# Epoch 149/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1357 - accuracy: 0.5938
# Epoch 150/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1271 - accuracy: 0.5938
# Epoch 151/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1180 - accuracy: 0.6146
# Epoch 152/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1090 - accuracy: 0.6146
# Epoch 153/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1004 - accuracy: 0.6146
# Epoch 154/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0914 - accuracy: 0.6042
# Epoch 155/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0828 - accuracy: 0.6042
# Epoch 156/500
# 3/3 [==============================] - 0s 11ms/step - loss: 1.0752 - accuracy: 0.6146
# Epoch 157/500
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0661 - accuracy: 0.6250
# Epoch 158/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0568 - accuracy: 0.6250
# Epoch 159/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0485 - accuracy: 0.6250
# Epoch 160/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0394 - accuracy: 0.6250
# Epoch 161/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0312 - accuracy: 0.6250
# Epoch 162/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0233 - accuracy: 0.6250
# Epoch 163/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0142 - accuracy: 0.6250
# Epoch 164/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0067 - accuracy: 0.6250
# Epoch 165/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9984 - accuracy: 0.6354
# Epoch 166/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9905 - accuracy: 0.6250
# Epoch 167/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9826 - accuracy: 0.6250
# Epoch 168/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9728 - accuracy: 0.6354
# Epoch 169/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9656 - accuracy: 0.6354
# Epoch 170/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9577 - accuracy: 0.6562
# Epoch 171/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9496 - accuracy: 0.6354
# Epoch 172/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9419 - accuracy: 0.6354
# Epoch 173/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9337 - accuracy: 0.6562
# Epoch 174/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9263 - accuracy: 0.6562
# Epoch 175/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9187 - accuracy: 0.6771
# Epoch 176/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9112 - accuracy: 0.6771
# Epoch 177/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9031 - accuracy: 0.6771
# Epoch 178/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8955 - accuracy: 0.6771
# Epoch 179/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8887 - accuracy: 0.6771
# Epoch 180/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8812 - accuracy: 0.6771
# Epoch 181/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8740 - accuracy: 0.6771
# Epoch 182/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8663 - accuracy: 0.6875
# Epoch 183/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8587 - accuracy: 0.6875
# Epoch 184/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8521 - accuracy: 0.7083
# Epoch 185/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8447 - accuracy: 0.7083
# Epoch 186/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8377 - accuracy: 0.7083
# Epoch 187/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8313 - accuracy: 0.7083
# Epoch 188/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8245 - accuracy: 0.7083
# Epoch 189/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8173 - accuracy: 0.7083
# Epoch 190/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8108 - accuracy: 0.7188
# Epoch 191/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8031 - accuracy: 0.7396
# Epoch 192/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7974 - accuracy: 0.7500
# Epoch 193/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7903 - accuracy: 0.7500
# Epoch 194/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7833 - accuracy: 0.7500
# Epoch 195/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7765 - accuracy: 0.7500
# Epoch 196/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7701 - accuracy: 0.7500
# Epoch 197/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7638 - accuracy: 0.7500
# Epoch 198/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7577 - accuracy: 0.7500
# Epoch 199/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7508 - accuracy: 0.7500
# Epoch 200/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7448 - accuracy: 0.7500
# Epoch 201/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7385 - accuracy: 0.7500
# Epoch 202/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7323 - accuracy: 0.7604
# Epoch 203/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7259 - accuracy: 0.7604
# Epoch 204/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7205 - accuracy: 0.7917
# Epoch 205/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7142 - accuracy: 0.7917
# Epoch 206/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7073 - accuracy: 0.7917
# Epoch 207/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7026 - accuracy: 0.7917
# Epoch 208/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6962 - accuracy: 0.8125
# Epoch 209/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6904 - accuracy: 0.8333
# Epoch 210/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6841 - accuracy: 0.8125
# Epoch 211/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6797 - accuracy: 0.7917
# Epoch 212/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6733 - accuracy: 0.8229
# Epoch 213/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6693 - accuracy: 0.8542
# Epoch 214/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6618 - accuracy: 0.8333
# Epoch 215/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6563 - accuracy: 0.8021
# Epoch 216/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6509 - accuracy: 0.8125
# Epoch 217/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6455 - accuracy: 0.8854
# Epoch 218/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6394 - accuracy: 0.8958
# Epoch 219/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6343 - accuracy: 0.9062
# Epoch 220/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6289 - accuracy: 0.9062
# Epoch 221/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6238 - accuracy: 0.9062
# Epoch 222/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6185 - accuracy: 0.9167
# Epoch 223/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6132 - accuracy: 0.9271
# Epoch 224/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6079 - accuracy: 0.9271
# Epoch 225/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6026 - accuracy: 0.9375
# Epoch 226/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5977 - accuracy: 0.9271
# Epoch 227/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5922 - accuracy: 0.9271
# Epoch 228/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5871 - accuracy: 0.9375
# Epoch 229/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5819 - accuracy: 0.9271
# Epoch 230/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5765 - accuracy: 0.9375
# Epoch 231/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5718 - accuracy: 0.9375
# Epoch 232/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5660 - accuracy: 0.9271
# Epoch 233/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5611 - accuracy: 0.9271
# Epoch 234/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5564 - accuracy: 0.9375
# Epoch 235/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5511 - accuracy: 0.9375
# Epoch 236/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5463 - accuracy: 0.9375
# Epoch 237/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5405 - accuracy: 0.9375
# Epoch 238/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5358 - accuracy: 0.9375
# Epoch 239/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5312 - accuracy: 0.9375
# Epoch 240/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5264 - accuracy: 0.9375
# Epoch 241/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5212 - accuracy: 0.9375
# Epoch 242/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5169 - accuracy: 0.9375
# Epoch 243/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 0.9375
# Epoch 244/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5070 - accuracy: 0.9375
# Epoch 245/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5020 - accuracy: 0.9375
# Epoch 246/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4980 - accuracy: 0.9375
# Epoch 247/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4943 - accuracy: 0.9375
# Epoch 248/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4886 - accuracy: 0.9375
# Epoch 249/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4847 - accuracy: 0.9375
# Epoch 250/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4794 - accuracy: 0.9375
# Epoch 251/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4757 - accuracy: 0.9375
# Epoch 252/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4713 - accuracy: 0.9375
# Epoch 253/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4659 - accuracy: 0.9375
# Epoch 254/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4617 - accuracy: 0.9375
# Epoch 255/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4575 - accuracy: 0.9375
# Epoch 256/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4532 - accuracy: 0.9375
# Epoch 257/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4490 - accuracy: 0.9375
# Epoch 258/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4450 - accuracy: 0.9375
# Epoch 259/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4407 - accuracy: 0.9375
# Epoch 260/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4364 - accuracy: 0.9375
# Epoch 261/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4319 - accuracy: 0.9375
# Epoch 262/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4277 - accuracy: 0.9375
# Epoch 263/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4239 - accuracy: 0.9375
# Epoch 264/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4201 - accuracy: 0.9375
# Epoch 265/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4152 - accuracy: 0.9375
# Epoch 266/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4114 - accuracy: 0.9375
# Epoch 267/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4074 - accuracy: 0.9375
# Epoch 268/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4040 - accuracy: 0.9375
# Epoch 269/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3995 - accuracy: 0.9375
# Epoch 270/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3961 - accuracy: 0.9375
# Epoch 271/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3922 - accuracy: 0.9375
# Epoch 272/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3889 - accuracy: 0.9375
# Epoch 273/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.3837 - accuracy: 0.9375
# Epoch 274/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3805 - accuracy: 0.9375
# Epoch 275/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3767 - accuracy: 0.9375
# Epoch 276/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3721 - accuracy: 0.9375
# Epoch 277/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3690 - accuracy: 0.9375
# Epoch 278/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3646 - accuracy: 0.9479
# Epoch 279/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3605 - accuracy: 0.9479
# Epoch 280/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3573 - accuracy: 0.9479
# Epoch 281/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3532 - accuracy: 0.9479
# Epoch 282/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3499 - accuracy: 0.9479
# Epoch 283/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3460 - accuracy: 0.9479
# Epoch 284/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3426 - accuracy: 0.9479
# Epoch 285/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3390 - accuracy: 0.9479
# Epoch 286/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3353 - accuracy: 0.9479
# Epoch 287/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3330 - accuracy: 0.9479
# Epoch 288/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3287 - accuracy: 0.9479
# Epoch 289/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3256 - accuracy: 0.9479
# Epoch 290/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3230 - accuracy: 0.9479
# Epoch 291/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3191 - accuracy: 0.9479
# Epoch 292/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3158 - accuracy: 0.9479
# Epoch 293/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3123 - accuracy: 0.9479
# Epoch 294/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3090 - accuracy: 0.9479
# Epoch 295/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3059 - accuracy: 0.9479
# Epoch 296/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3040 - accuracy: 0.9479
# Epoch 297/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3004 - accuracy: 0.9479
# Epoch 298/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.9479
# Epoch 299/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2942 - accuracy: 0.9479
# Epoch 300/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2911 - accuracy: 0.9479
# Epoch 301/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2879 - accuracy: 0.9479
# Epoch 302/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2858 - accuracy: 0.9479
# Epoch 303/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2825 - accuracy: 0.9479
# Epoch 304/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2796 - accuracy: 0.9479
# Epoch 305/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2772 - accuracy: 0.9479
# Epoch 306/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2738 - accuracy: 0.9479
# Epoch 307/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2722 - accuracy: 0.9479
# Epoch 308/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2689 - accuracy: 0.9479
# Epoch 309/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2659 - accuracy: 0.9479
# Epoch 310/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2633 - accuracy: 0.9479
# Epoch 311/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2612 - accuracy: 0.9479
# Epoch 312/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2587 - accuracy: 0.9375
# Epoch 313/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2561 - accuracy: 0.9375
# Epoch 314/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2530 - accuracy: 0.9479
# Epoch 315/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2510 - accuracy: 0.9479
# Epoch 316/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2487 - accuracy: 0.9479
# Epoch 317/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2459 - accuracy: 0.9479
# Epoch 318/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2437 - accuracy: 0.9479
# Epoch 319/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2414 - accuracy: 0.9479
# Epoch 320/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2387 - accuracy: 0.9479
# Epoch 321/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2372 - accuracy: 0.9479
# Epoch 322/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2342 - accuracy: 0.9479
# Epoch 323/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2322 - accuracy: 0.9479
# Epoch 324/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2307 - accuracy: 0.9479
# Epoch 325/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2280 - accuracy: 0.9479
# Epoch 326/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2255 - accuracy: 0.9479
# Epoch 327/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2236 - accuracy: 0.9479
# Epoch 328/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.9479
# Epoch 329/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2190 - accuracy: 0.9479
# Epoch 330/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2172 - accuracy: 0.9479
# Epoch 331/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2153 - accuracy: 0.9479
# Epoch 332/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2134 - accuracy: 0.9479
# Epoch 333/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2114 - accuracy: 0.9479
# Epoch 334/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2097 - accuracy: 0.9479
# Epoch 335/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2078 - accuracy: 0.9479
# Epoch 336/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2067 - accuracy: 0.9479
# Epoch 337/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9479
# Epoch 338/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2016 - accuracy: 0.9479
# Epoch 339/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2002 - accuracy: 0.9375
# Epoch 340/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1991 - accuracy: 0.9375
# Epoch 341/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1969 - accuracy: 0.9479
# Epoch 342/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1959 - accuracy: 0.9375
# Epoch 343/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1932 - accuracy: 0.9479
# Epoch 344/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1915 - accuracy: 0.9479
# Epoch 345/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1904 - accuracy: 0.9375
# Epoch 346/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1884 - accuracy: 0.9479
# Epoch 347/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1866 - accuracy: 0.9583
# Epoch 348/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.9583
# Epoch 349/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9583
# Epoch 350/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1830 - accuracy: 0.9479
# Epoch 351/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1801 - accuracy: 0.9583
# Epoch 352/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1784 - accuracy: 0.9583
# Epoch 353/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1773 - accuracy: 0.9583
# Epoch 354/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1756 - accuracy: 0.9583
# Epoch 355/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1740 - accuracy: 0.9583
# Epoch 356/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.9583
# Epoch 357/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1714 - accuracy: 0.9583
# Epoch 358/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1698 - accuracy: 0.9583
# Epoch 359/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1684 - accuracy: 0.9583
# Epoch 360/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1668 - accuracy: 0.9583
# Epoch 361/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1654 - accuracy: 0.9583
# Epoch 362/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1642 - accuracy: 0.9688
# Epoch 363/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1626 - accuracy: 0.9688
# Epoch 364/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1619 - accuracy: 0.9688
# Epoch 365/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1603 - accuracy: 0.9792
# Epoch 366/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1590 - accuracy: 0.9792
# Epoch 367/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1573 - accuracy: 0.9792
# Epoch 368/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1562 - accuracy: 0.9792
# Epoch 369/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 0.9792
# Epoch 370/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1535 - accuracy: 0.9792
# Epoch 371/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1525 - accuracy: 0.9792
# Epoch 372/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1514 - accuracy: 0.9792
# Epoch 373/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1503 - accuracy: 0.9792
# Epoch 374/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1486 - accuracy: 0.9792
# Epoch 375/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1475 - accuracy: 0.9792
# Epoch 376/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1467 - accuracy: 0.9792
# Epoch 377/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1459 - accuracy: 0.9792
# Epoch 378/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1441 - accuracy: 0.9792
# Epoch 379/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1428 - accuracy: 0.9792
# Epoch 380/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1424 - accuracy: 0.9688
# Epoch 381/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1415 - accuracy: 0.9792
# Epoch 382/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1397 - accuracy: 0.9792
# Epoch 383/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1387 - accuracy: 0.9688
# Epoch 384/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1376 - accuracy: 0.9792
# Epoch 385/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1366 - accuracy: 0.9792
# Epoch 386/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1356 - accuracy: 0.9792
# Epoch 387/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1349 - accuracy: 0.9792
# Epoch 388/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1333 - accuracy: 0.9792
# Epoch 389/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1336 - accuracy: 0.9792
# Epoch 390/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1318 - accuracy: 0.9792
# Epoch 391/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1307 - accuracy: 0.9792
# Epoch 392/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1297 - accuracy: 0.9792
# Epoch 393/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1287 - accuracy: 0.9792
# Epoch 394/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1278 - accuracy: 0.9792
# Epoch 395/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1267 - accuracy: 0.9792
# Epoch 396/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1255 - accuracy: 0.9792
# Epoch 397/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1249 - accuracy: 0.9792
# Epoch 398/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1239 - accuracy: 0.9792
# Epoch 399/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1229 - accuracy: 0.9792
# Epoch 400/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1218 - accuracy: 0.9792
# Epoch 401/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1207 - accuracy: 0.9792
# Epoch 402/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1202 - accuracy: 0.9792
# Epoch 403/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1198 - accuracy: 0.9792
# Epoch 404/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1183 - accuracy: 0.9792
# Epoch 405/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1179 - accuracy: 0.9792
# Epoch 406/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1168 - accuracy: 0.9792
# Epoch 407/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1159 - accuracy: 0.9792
# Epoch 408/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1150 - accuracy: 0.9792
# Epoch 409/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1143 - accuracy: 0.9792
# Epoch 410/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1136 - accuracy: 0.9792
# Epoch 411/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1131 - accuracy: 0.9792
# Epoch 412/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1124 - accuracy: 0.9792
# Epoch 413/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1112 - accuracy: 0.9792
# Epoch 414/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1105 - accuracy: 0.9792
# Epoch 415/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1097 - accuracy: 0.9792
# Epoch 416/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1096 - accuracy: 0.9792
# Epoch 417/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1082 - accuracy: 0.9792
# Epoch 418/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1071 - accuracy: 0.9792
# Epoch 419/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1068 - accuracy: 0.9792
# Epoch 420/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1061 - accuracy: 0.9792
# Epoch 421/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1049 - accuracy: 0.9792
# Epoch 422/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1044 - accuracy: 0.9792
# Epoch 423/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1046 - accuracy: 0.9792
# Epoch 424/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1033 - accuracy: 0.9792
# Epoch 425/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1026 - accuracy: 0.9792
# Epoch 426/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1020 - accuracy: 0.9792
# Epoch 427/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1012 - accuracy: 0.9792
# Epoch 428/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1004 - accuracy: 0.9792
# Epoch 429/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0999 - accuracy: 0.9792
# Epoch 430/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0991 - accuracy: 0.9792
# Epoch 431/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0991 - accuracy: 0.9792
# Epoch 432/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9792
# Epoch 433/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0972 - accuracy: 0.9792
# Epoch 434/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0967 - accuracy: 0.9792
# Epoch 435/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0964 - accuracy: 0.9792
# Epoch 436/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0953 - accuracy: 0.9792
# Epoch 437/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0951 - accuracy: 0.9792
# Epoch 438/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0942 - accuracy: 0.9792
# Epoch 439/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0935 - accuracy: 0.9792
# Epoch 440/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0933 - accuracy: 0.9792
# Epoch 441/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0925 - accuracy: 0.9792
# Epoch 442/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0925 - accuracy: 0.9792
# Epoch 443/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0913 - accuracy: 0.9792
# Epoch 444/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0909 - accuracy: 0.9792
# Epoch 445/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0906 - accuracy: 0.9792
# Epoch 446/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0898 - accuracy: 0.9792
# Epoch 447/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0904 - accuracy: 0.9688
# Epoch 448/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0888 - accuracy: 0.9792
# Epoch 449/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0889 - accuracy: 0.9792
# Epoch 450/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0877 - accuracy: 0.9792
# Epoch 451/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0871 - accuracy: 0.9792
# Epoch 452/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0868 - accuracy: 0.9792
# Epoch 453/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0872 - accuracy: 0.9688
# Epoch 454/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0862 - accuracy: 0.9792
# Epoch 455/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0857 - accuracy: 0.9792
# Epoch 456/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0850 - accuracy: 0.9792
# Epoch 457/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0846 - accuracy: 0.9792
# Epoch 458/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0840 - accuracy: 0.9792
# Epoch 459/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0834 - accuracy: 0.9792
# Epoch 460/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0828 - accuracy: 0.9792
# Epoch 461/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.9792
# Epoch 462/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0811 - accuracy: 0.9792
# Epoch 463/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0819 - accuracy: 0.9688
# Epoch 464/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0817 - accuracy: 0.9688
# Epoch 465/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0800 - accuracy: 0.9792
# Epoch 466/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0794 - accuracy: 0.9792
# Epoch 467/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0792 - accuracy: 0.9792
# Epoch 468/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0784 - accuracy: 0.9792
# Epoch 469/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0784 - accuracy: 0.9792
# Epoch 470/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0777 - accuracy: 0.9792
# Epoch 471/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0779 - accuracy: 0.9792
# Epoch 472/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0768 - accuracy: 0.9792
# Epoch 473/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0764 - accuracy: 0.9792
# Epoch 474/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9688
# Epoch 475/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0764 - accuracy: 0.9688
# Epoch 476/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9688
# Epoch 477/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0747 - accuracy: 0.9688
# Epoch 478/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0747 - accuracy: 0.9792
# Epoch 479/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.9792
# Epoch 480/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0738 - accuracy: 0.9792
# Epoch 481/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0731 - accuracy: 0.9792
# Epoch 482/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0730 - accuracy: 0.9792
# Epoch 483/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0720 - accuracy: 0.9792
# Epoch 484/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0720 - accuracy: 0.9792
# Epoch 485/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0718 - accuracy: 0.9792
# Epoch 486/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0716 - accuracy: 0.9792
# Epoch 487/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0707 - accuracy: 0.9792
# Epoch 488/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0701 - accuracy: 0.9792
# Epoch 489/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0700 - accuracy: 0.9792
# Epoch 490/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0698 - accuracy: 0.9792
# Epoch 491/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0696 - accuracy: 0.9792
# Epoch 492/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0691 - accuracy: 0.9792
# Epoch 493/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0698 - accuracy: 0.9688
# Epoch 494/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0689 - accuracy: 0.9792
# Epoch 495/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0680 - accuracy: 0.9792
# Epoch 496/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0682 - accuracy: 0.9792
# Epoch 497/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0676 - accuracy: 0.9792
# Epoch 498/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0671 - accuracy: 0.9792
# Epoch 499/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0667 - accuracy: 0.9792
# Epoch 500/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 0.9688

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model/assets

# %%
def webscraper(x):
  from urllib.request import Request, urlopen
  from bs4 import BeautifulSoup
  import requests
  from random import randint

  #x = inp

  root = "https://www.google.com"
  link = "https://www.google.com/search?q=top+10+{}+movies&oq=top+&aqs=chrome.0.69i59l3j69i57j69i60l4.651j0j4&sourceid=chrome&ie=UTF-8".format(x)
  results = []

  req = Request(link, headers = {"User-Agent": "Mozilla/5.0"})
  webpage = urlopen(req).read()
  with requests.Session() as c:
    soup = BeautifulSoup(webpage, "html5lib")
    #print(soup)
    for item in soup.find_all('div', attrs = {"class": "RWuggc"}):
      results.append(item)

  titles = []
  
  for word in results:
    for j in word:
      for i in j:
        for p in i:
          is_year_of_pub = True                          #filtering out years of publication; filters everything that consists only of numbers, so a movie like 2012 will not make it to the recommendation
          for char in p:
            if ord(char) < 48 or ord(char) > 57:
              is_year_of_pub = False
              break
          if is_year_of_pub == False:                     #Only if p is not a string of just numbers, it is put in the titles list
            titles.append(p)

  #print(titles)
  end_of_titles = len(titles)
  movie_index = randint(0, end_of_titles )
  movie_index_end = movie_index + 1
  return str(*(titles[movie_index:movie_index_end]))

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle
translator = Translator()

#with open("intents.json") as file:
#    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20

    language_detect = input("Please state the language you would like to talk in to Moviebot? \n (State the language in English please) ")
    language_detect = language_detect.lower()
    language_lib = googletrans.LANGCODES

    
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        #language = (translator.detect(inp)).lang
        language = language_lib[language_detect]
        inp_translated = (translator.translate(inp)).text
        if inp_translated.lower() == "quit":
            break
        


        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp_translated]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])

        for i in data['intents']:
          if i['tag'] == tag:
            answer = np.random.choice(i['responses'])
            trans_answer = translator.translate(answer, dest = language).text
            print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)

        if tag == "thanks":
            answer = np.random.choice(i['responses'])
            trans_answer = translator.translate(answer, dest = language).text
            #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
            break
        if tag == "genres":
          answer = np.random.choice(i['responses'])
          trans_answer = translator.translate(answer, dest = language).text
          #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
          print(translator.translate("What about: ", dest = language).text, webscraper(inp_translated))
          genre = inp_translated
        if tag == "another":
          answer = np.random.choice(i['responses'])
          trans_answer = translator.translate(answer, dest = language).text
          #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , trans_answer)
          print(webscraper(genre))
        
          
          



        #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# Please state the language you would like to talk in to Moviebot?
#  (State the language in English please) English
# User: quit

# %%
#print(googletrans.LANGUAGES)

example = "Hallo, hoe gaat het?"
transl_ex = (translator.translate(example)).text
print(transl_ex)


language = (translator.detect("Lorem Ipsum")).lang
print(language)

print((translator.translate(transl_ex, dest = language)).text)

#translations = translator.translate(['The quick brown fox', 'jumps over', 'the lazy dog'], dest='ko')
#for translation in translations:
#print(translation.origin, ' -> ', translation.text)
# The quick brown fox  ->  빠른 갈색 여우
# jumps over  ->  이상 점프
# the lazy dog  ->  게으른 개
# Out:
# Hello how are you?
# la
# Salve, quam vos?

# %%
titles = []
for word in results:
  for j in word:
    for i in j:
      for p in i:
        titles.append(p)

print(titles)

# %%
#googletrans.LANGCODES

#print("In what language would you like to talk to Moviebot?")
language_detect = input("In what language would you like to talk to Moviebot? ")
language_detect = language_detect.lower()
language_lib = googletrans.LANGCODES

print(language_lib[language_detect])
# Out:
# In what language would you like to talk to Moviebot? Dutch
# nl

# %%
#Testing
#1. Unit Testing
def LangDetectTest():
  correct_input = "Lorem Ipsum"
  incorrect_input = ""

  outcome1 = (translator.detect(correct_input)).lang
  if outcome1 == "la":
    test1 = "Success"
  else:
    test1 = "Failure"
  try:
    outcome2 = (translator.detect(incorrect_input)).lang
    test2 = "Failure"
  except:
    test2 = "Failure"
    return "Result of language detector test with correct input: {}\n\
Result of language detector test with incorrect input: {} caused by ERROR".format(test1, test2)
  else:
    return "Result of language detector test with correct input: {};\n\
Result of language detector test with incorrect input: {}".format(test1, test2)


#2. Component/Integration testing

def WebscraperTest():
  known_genre = "action"
  unknown_genre = "bruh"

  outcome1 = webscraper(known_genre)
  if type(outcome1) == str and len(outcome1) > 0:
    test1 = "Success"
  else:
    test1 = "Failure"
  try:
    outcome2 = webscraper(unknown_genre)
    test2 = "Failure"
  except:
    test2 = "Failure"
    return "Result of webscraper test with a known genre as input: {}\n\
    Result of webscraper test with an unknown genre as input: {} caused by ERROR".format(test1, test2)
  else:
    return "Result of webscraper test with a known genre as input: {}\n\
Result of webscraper test with an unknown genre as input: {}"
  .format(test1, test2)


print(LangDetectTest())
print(WebscraperTest())
# Out:
# Result of language detector test with correct input: Success
# Result of language detector test with incorrect input: Failure caused by ERROR
# Result of webscraper test with a known genre as input: Failure
# Result of webscraper test with an unknown genre as input: Failure
